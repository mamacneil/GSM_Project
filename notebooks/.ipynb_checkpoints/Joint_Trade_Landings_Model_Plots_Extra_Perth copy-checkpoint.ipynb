# %% [markdown]
# # Model plots for shark and ray meat landings and trade applied to 2014-2019 data

# %%
import os

import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import pytensor.tensor as pyt
import seaborn as sns
import pdb
from matplotlib.gridspec import GridSpec
import xarray as xr
import xarray_einstats
import rdata as rd
import networkx as nx
from mpl_toolkits.basemap import Basemap as bm
import geopandas as gpd

from matplotlib.path import Path
import matplotlib.patches as patches
from matplotlib.legend_handler import HandlerPatch
from matplotlib.legend import Legend

# %%
# Set figure style.
az.style.use("arviz-darkgrid")
bd = os.getcwd() + "/../Data/"
bf = os.getcwd() + "/../Figures/"

# %%
# Helper functions
def indexall(L):
    poo = []
    for p in L:
        if not p in poo:
            poo.append(p)
    Ix = np.array([poo.index(p) for p in L])
    return poo, Ix


# Helper functions
match = lambda a, b: np.array([b.index(x) if x in b else None for x in a])


def unique(series: pd.Series):
    "Helper function to sort and isolate unique values of a Pandas Series"
    return series.sort_values().unique()


def pairplot_divergence(trace, basevar, targetvar, ax=None, divergence=True, color='C3', divergence_color='C2'):
    #theta = trace.get_values(varname=basevar, combine=True)[:, 0]
    theta = trace.posterior[basevar].values.flatten()
    logtau = trace.posterior[targetvar].values.flatten()
    if not ax:
        _, ax = plt.subplots(1, 1, figsize=(10, 5))
    ax.plot(theta, logtau, 'o', color=color, alpha=.5)
    if divergence:
        divergent = trace.sample_stats.diverging.values.flatten()
        ax.plot(theta[divergent], logtau[divergent], 'o', color=divergence_color)
    ax.set_xlabel(basevar)
    ax.set_ylabel(targetvar)
    ax.set_title('scatter plot between log('+targetvar+') and '+basevar);
    return ax

# A small wrapper function for displaying the MCMC sampler diagnostics as above
def report_trace(trace,basevar,targetvar,logscale=False):
    # plot the trace of log(tau)
    pm.plot_trace({targetvar: trace.posterior[targetvar].values.flatten()});

    # plot the estimate for the mean of log(τ) cumulating mean
    if logscale:
        logtau = np.log(trace.posterior[targetvar].values.flatten())
    else:
        logtau = trace.posterior[targetvar].values.flatten()
    mlogtau = [np.mean(logtau[:i]) for i in np.arange(1, len(logtau))]
    plt.figure(figsize=(15, 4))
    #plt.axhline(0.7657852, lw=2.5, color='gray')
    plt.plot(mlogtau, lw=2.5)
    plt.ylim(0, 2)
    plt.xlabel('Iteration')
    plt.ylabel('MCMC mean of log('+targetvar+')')
    plt.title('MCMC estimation of log('+targetvar+')')
    plt.show()

    # display the total number and percentage of divergent
    divergent = trace.sample_stats.diverging.values.flatten()
    print('Number of Divergent %d' % divergent.nonzero()[0].size)
    divperc = divergent.nonzero()[0].size / len(trace) * 100
    print('Percentage of Divergent %.1f' % divperc)

    # scatter plot between log(tau) and theta[0]
    # for the identifcation of the problematic neighborhoods in parameter space
    pairplot_divergence(trace,basevar,targetvar);

def ssq(x,y):
    return (y-x)**2

# %% [markdown]
# ## Load data

# %%
# Load data
exec(open("Joint_Trade_Landings_Data_AUGM_Perth.py").read())
# Out:
# Data loaded!
# <string>:833: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# <string>:833: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# <string>:833: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# <string>:833: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# <string>:833: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.

# %%
# Numerical year
sdata['Year'] = sdata.year_spp_id+2012
txdata['Year'] = txdata.year_tax_id+2012
# Long country name
sdata['Country'] = biggest_countries_long[sdata.country_spp_id]
txdata['Country'] = biggest_countries_long[txdata.country_tax_id]
# un-log landings
sdata['Reported_species_landings'] = np.exp(sdata['logReported_species_landings'])
txdata['Reported_taxon_landings'] = np.exp(txdata['logReported_taxon_landings'])

# Make agumented objects
sdata_aug = sdata
txdata_aug = txdata

# %%
# Grab augmented country list
biggest_countries_long_a = biggest_countries_long
biggest_countries_a = biggest_countries
country_a = country_

# %%
# Load data
exec(open("Joint_Trade_Landings_Data_Perth.py").read())
# Out:
# <string>:520: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Data loaded!
# <string>:819: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# <string>:819: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# <string>:819: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# <string>:819: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# <string>:819: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.

# %% [markdown]
# # Import landings inference object

# %%
# Import MultiTrace objects
idata_landings_x = az.from_netcdf("idata-landings-model_Perth.nc")
idata_trade_x = az.from_netcdf("idata-trade-model_Perth.nc")

# Import MultiTrace objects
idata_landings_a = az.from_netcdf("idata-landings-model_AUGM_Perth.nc")
idata_trade_a = az.from_netcdf("idata-trade-model_AUGM_Perth.nc")

# %%
# Import species by habitat
hdata = pd.read_csv(bd+'Habitat.csv')
hdata = hdata[hdata.Superorder!='Holocephalimorpha']

# %%
# ArviZ doesn't handle MultiIndex yet
# Making it aware of the real data labeling at the obs level
more_coords = {
    "Exporter": ("exporter", biggest_countries_long),
    "Importer": ("importer", biggest_countries_long)
}

more_coords_a = {
    "Exporter": ("exporter", biggest_countries_long_a),
    "Importer": ("importer", biggest_countries_long_a)
}

# Update landings coords
idata_landings_x.prior = idata_landings_x.prior.assign_coords(more_coords)
idata_landings_x.prior_predictive = idata_landings_x.prior_predictive.assign_coords(more_coords)
idata_landings_x.posterior = idata_landings_x.posterior.assign_coords(more_coords)
idata_landings_x.posterior_predictive = idata_landings_x.posterior_predictive.assign_coords(
    more_coords
)
idata_landings_x.observed_data = idata_landings_x.observed_data.assign_coords(more_coords)
idata_landings_x.constant_data = idata_landings_x.constant_data.assign_coords(more_coords)

# Update trade coords
idata_trade_x.prior = idata_trade_x.prior.assign_coords(more_coords)
idata_trade_x.prior_predictive = idata_trade_x.prior_predictive.assign_coords(more_coords)
idata_trade_x.posterior = idata_trade_x.posterior.assign_coords(more_coords)
idata_trade_x.posterior_predictive = idata_trade_x.posterior_predictive.assign_coords(
    more_coords
)
idata_trade_x.observed_data = idata_trade_x.observed_data.assign_coords(more_coords)
idata_trade_x.constant_data = idata_trade_x.constant_data.assign_coords(more_coords)


# Update landings coords
idata_landings_a.prior = idata_landings_a.prior.assign_coords(more_coords_a)
idata_landings_a.prior_predictive = idata_landings_a.prior_predictive.assign_coords(more_coords_a)
idata_landings_a.posterior = idata_landings_a.posterior.assign_coords(more_coords_a)
idata_landings_a.posterior_predictive = idata_landings_a.posterior_predictive.assign_coords(
    more_coords_a
)
idata_landings_x.observed_data = idata_landings_a.observed_data.assign_coords(more_coords_a)
idata_landings_x.constant_data = idata_landings_a.constant_data.assign_coords(more_coords_a)

# Update trade coords
idata_trade_a.prior = idata_trade_a.prior.assign_coords(more_coords_a)
idata_trade_a.prior_predictive = idata_trade_a.prior_predictive.assign_coords(more_coords_a)
idata_trade_a.posterior = idata_trade_a.posterior.assign_coords(more_coords_a)
idata_trade_a.posterior_predictive = idata_trade_a.posterior_predictive.assign_coords(
    more_coords_a
)
idata_trade_a.observed_data = idata_trade_a.observed_data.assign_coords(more_coords_a)
idata_trade_a.constant_data = idata_trade_a.constant_data.assign_coords(more_coords_a)

#"""

# %% [markdown]
# # Global summaries

# %% [markdown]
# ## Plot temporal trends

# %%
# Annual augmented species landings
SppLandingsYear = (sdata_aug
                   .groupby('Year').sum()
                   .reset_index()[['Year','Reported_species_landings']]
                   .rename(columns={'Reported_species_landings':'Species'})
                  )
# Annual augmented taxon landings
TaxLandingsYear = (txdata_aug
                    .groupby('Year').sum()
                    .reset_index()[['Year','Reported_taxon_landings']]
                    .rename(columns={'Reported_taxon_landings':'NEI'}))
# Landings/year
LandingsYear = SppLandingsYear
LandingsYear['NEI'] = TaxLandingsYear.NEI
LandingsYear = LandingsYear.set_index(LandingsYear.Year).drop(columns=('Year'))

# %% [markdown]
# ## Supplemental figure - NEI landings proportion

# %%
p = sns.lineplot(data=LandingsYear/1000, palette="tab10", linewidth=2.5)
p.set(yticks=(200,300,400,500,600),ylabel=('Total landings (kt)'))
plt.savefig(bf+'/Global/'+'Species_NEI_Landings.jpg',dpi=300);

# %%
# Average NEI landings proportion
np.mean(LandingsYear.NEI/(LandingsYear.NEI+LandingsYear.Species))
# Out:
# 0.7048447338758752

# %% [markdown]
# ## Plot reported and augmented latent landings

# %%
# Plot reported and augmented estimated latent landings
c_landings_x = idata_landings_x.posterior['Latent_landings'].sum('species').to_dataframe().reset_index()
c_landings_x['Dataset'] = 'Reported'
c_landings_a = idata_landings_a.posterior['Latent_landings'].sum('species').to_dataframe().reset_index()
c_landings_a['Dataset'] = 'Augmented'
c_landings = c_landings_x.merge(c_landings_a,how='outer')
c_landings.Exporter[c_landings.Exporter=="Other Asia, nes"] = 'Taiwan'
plot_order = c_landings.groupby('Exporter')['Latent_landings'].sum().sort_values(ascending=False).index.values
# Out:
# /var/folders/0t/qrl_lm21285bvxnv0dg58ycm0000gn/T/ipykernel_85698/2771623734.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_landings.Exporter[c_landings.Exporter=="Other Asia, nes"] = 'Taiwan'

# %%
# Draw a nested barplot
g = sns.catplot(
    data=c_landings, kind="bar",
    y="Exporter", x="Latent_landings", hue="Dataset", order=plot_order,
    errorbar="ci", palette="dark", alpha=.6, height=12,
    
)
g.despine(left=True)
g.set_axis_labels("Total landings (t/yr)","")
#g.legend.set_title("")
g.legend.set_title("Annual landings 2012-2019")
plt.savefig(bf+'/Global/'+'Latent_landings_reported_augmented.jpg',dpi=300);
# Out:
# /Users/aaronmacneil/miniforge3/envs/gsm-project/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Grab top N exporters
N = 35
exps = (c_landings.drop(columns=['exporter','Dataset'])
        .groupby('Exporter').sum().reset_index()
        .sort_values('Latent_landings',ascending=False)
        .Exporter[:N].values
       )
# Draw a nested barplot
g = sns.catplot(
    data=c_landings[c_landings.Exporter.isin(exps)], kind="bar",
    y="Exporter", x="Latent_landings", hue="Dataset", order=plot_order[match(exps,list(plot_order))],
    errorbar=('ci', 95), palette="dark", alpha=.6, height=7,
    
)
g.despine(left=True)
g.set_axis_labels("Total landings (t/yr)","")
#g.legend.set_title("")
g.legend.set_title("Annual landings 2012-2019")
plt.savefig(bf+'/Global/'+'Latent_landings_reported_augmented_'+str(N)+'.jpg',dpi=300);
# Out:
# /Users/aaronmacneil/miniforge3/envs/gsm-project/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Estimated numbers of sharks and rays annually

# %%
tidata = pd.read_csv(bd+'tax_iucn_size.csv')

# %%
# Vector of mass - convert g to tonnes
meanmass = tidata.mass_max.values[match(idata_landings_a.posterior['Latent_landings'].species.values,list(tidata.species_binomial))]/1000000

# %%
# Estimated number of sharks landed annually
EstNsharks = (idata_landings_a.posterior['Latent_landings'].sum('exporter')/meanmass[None,None,])[:,:,group_=='sharks'].sum('species')
# Estimated number of rays landed annually
EstNrays = (idata_landings_a.posterior['Latent_landings'].sum('exporter')/meanmass[None,None,])[:,:,group_=='rays'].sum('species')

# %%
# Estimated number of sharks traded annually
EstNsharks_trade = (idata_trade_a.posterior['amount_exported'].sum('exporter')/meanmass[None,None,:,None])[:,:,group_=='sharks'].sum('species')
# Estimated number of rays traded annually
EstNrays_trade = (idata_trade_a.posterior['amount_exported'].sum('exporter')/meanmass[None,None,:,None])[:,:,group_=='rays'].sum('species')

# %%
# Proportion of rays in landings
idata_landings_a.posterior['Latent_landings'][:,:,:,group_=='rays'].sum()/idata_landings_x.posterior['Latent_landings'].sum()
# Out:
# <xarray.DataArray 'Latent_landings' ()>
# array(0.50154148)

# %%
# Proportion of rays in trade
idata_trade_a.posterior['amount_exported'][:,:,:,group_=='rays'].sum()/idata_trade_a.posterior['amount_exported'].sum()
# Out:
# <xarray.DataArray 'amount_exported' ()>
# array(0.40666558)

# %%
fig, ax = plt.subplots(1, 2,figsize=(5,3))
fig.suptitle("Estimated Landings")

ax[0].set_title("Sharks")
az.plot_dist(EstNsharks/1000000, color="C0", ax=ax[0])
ax[0].set_xlabel('Millions')

ax[1].set_title("Rays")
az.plot_dist(EstNrays/1000000, color="C1", ax=ax[1])
ax[1].set_xlabel('millions')
plt.savefig(bf+'/Global/'+'Estimated_individuals.jpg',dpi=300);

# %% [markdown]
# ## Plot top importers and exporters

# %%
# Traded+retained
trade_spp = (
    idata_trade_a.copy().posterior['amount_exported']
    .rename('')
    .assign_coords({"Group": ("species", group_),"Exporter": ("exporter", biggest_countries_long_a),"Importer": ("importer", biggest_countries_long_a)})
)

# Retain copy 
trade_spp_tot = trade_spp.copy()

# Domestic consumption
domestic_spp = trade_spp*0

# Store domestic and remove from trade
for c in country_a:
    # Add domestic consumption to domestic xarray
    domestic_spp.loc[dict(exporter=c,importer=c)] = trade_spp.sel(exporter=c,importer=c)
    # Remove domestic consumption from trade xarray
    trade_spp.loc[dict(exporter=c,importer=c)] = 0

# Split by group
total_shark_trade = trade_spp[:,:,:,group_=='sharks',:].sum(('species'))
total_ray_trade = trade_spp[:,:,:,group_=='rays',:].sum(('species'))

# Split by group for both trade and retained
total_shark = trade_spp_tot[:,:,:,group_=='sharks',:].sum(('species'))
total_ray = trade_spp_tot[:,:,:,group_=='rays',:].sum(('species'))

# %%
# Grab top N 
N = 20
plot_order_ex = trade_spp.sortby(trade_spp.sum(('chain','draw','importer','species')), ascending=False).exporter[:N]
plot_order_im = trade_spp.sortby(trade_spp.sum(('chain','draw','exporter','species')), ascending=False).importer[:N]
plot_order_co = trade_spp_tot.sortby(trade_spp_tot.sum(('chain','draw','exporter','species')), ascending=False).importer[:N]

# %%
# = = = = = Set up plot
az.style.use("arviz-darkgrid")
_, ax = plt.subplots(1,3,figsize=(15, 5))

# Exporters
az.plot_forest(
    [total_shark_trade.sum('importer').sel(exporter=plot_order_ex), total_ray_trade.sum('importer').sel(exporter=plot_order_ex)],
    model_names=["Sharks", "Rays"],
    figsize=(5, 12),
    combined=True,
    ax=ax[0]
)
tmp_lab = plot_order_ex.Exporter.to_numpy()[::-1]
tmp_lab[tmp_lab=="Other Asia, nes"] = 'Taiwan'
ax[0].set_yticklabels(tmp_lab)
ax[0].set_title("Top exporters")
ax[0].set_xlabel('(t)')

# Importers
az.plot_forest(
    [total_shark_trade.sum('exporter').sel(importer=plot_order_im), total_ray_trade.sum('exporter').sel(importer=plot_order_im)],
    model_names=["Sharks", "Rays"],
    figsize=(5, 12),
    combined=True,
    ax=ax[1]
)
tmp_lab = plot_order_im.Importer.to_numpy()[::-1]
tmp_lab[tmp_lab=="Other Asia, nes"] = 'Taiwan'
ax[1].set_yticklabels(tmp_lab)
ax[1].set_title("Top importers")
#ax[1].tick_params(axis='y', labelright=True, right=False)
#ax[1].tick_params(axis='y', labelleft=False, left=False)
ax[1].legend_.remove() 
ax[1].set_xlabel('(t)')


# Consumers
az.plot_forest(
    [total_shark.sum('exporter').sel(importer=plot_order_co), total_ray.sum('exporter').sel(importer=plot_order_co)],
    model_names=["Sharks", "Rays"],
    figsize=(5, 12),
    combined=True,
    ax=ax[2]
)
tmp_lab = plot_order_co.Importer.to_numpy()[::-1]
tmp_lab[tmp_lab=="Other Asia, nes"] = 'Taiwan'
ax[2].set_yticklabels(tmp_lab)
ax[2].set_title("Top consumers")
#ax[2].tick_params(axis='y', labelright=True, right=False)
#ax[2].tick_params(axis='y', labelleft=False, left=False)
ax[2].legend_.remove() 
ax[2].set_xlabel('(t)')

plt.tight_layout()
#plt.subplots_adjust(hspace=.0)
#plt.savefig(bf+'/Global/'+'Top_trading_nations.jpg',dpi=300);
# Out:
# /var/folders/0t/qrl_lm21285bvxnv0dg58ycm0000gn/T/ipykernel_85698/1176703283.py:54: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
# = = = = = Set up plot
az.style.use("arviz-darkgrid")
_, ax = plt.subplots(2,2,figsize=(12, 8))

az.plot_dist(EstNsharks/1000000, color="C0", ax=ax[0,0], label='Sharks', kind='hist')
az.plot_dist(EstNrays/1000000, color="C1", ax=ax[0,0], label='Rays', kind='hist')
ax[0,0].set_xticks((15,20,25))
ax[0,0].set_yticklabels("")
ax[0,0].set_xlabel('Millions')
ax[0,0].set_title('Annual trade')


# Exporters
az.plot_forest(
    [total_shark_trade.sum('importer').sel(exporter=plot_order_ex), total_ray_trade.sum('importer').sel(exporter=plot_order_ex)],
    model_names=["Sharks", "Rays"],
    figsize=(5, 12),
    combined=True,
    ax=ax[1,0]
)
tmp_lab = plot_order_ex.Exporter.to_numpy()[::-1]
tmp_lab[tmp_lab=="Other Asia, nes"] = 'Taiwan'
ax[1,0].set_yticklabels(tmp_lab)
ax[1,0].set_title("Top exporters")
ax[1,0].set_xlabel('(t)')
ax[1,0].legend_.remove() 

# Importers
az.plot_forest(
    [total_shark_trade.sum('exporter').sel(importer=plot_order_im), total_ray_trade.sum('exporter').sel(importer=plot_order_im)],
    model_names=["Sharks", "Rays"],
    figsize=(5, 12),
    combined=True,
    ax=ax[1,1]
)
tmp_lab = plot_order_im.Importer.to_numpy()[::-1]
tmp_lab[tmp_lab=="Other Asia, nes"] = 'Taiwan'
ax[1,1].set_yticklabels(tmp_lab)
ax[1,1].set_title("Top importers")
#ax[1,1].tick_params(axis='y', labelright=True, right=False)
#ax[1,1].tick_params(axis='y', labelleft=False, left=False)
ax[1,1].legend_.remove() 
ax[1,1].set_xlabel('(t)')
ax[1,1].yaxis.set_label_position("right")
ax[1,1].set_ylabel('')
ax[1,1].yaxis.tick_right()


# Consumers
az.plot_forest(
    [total_shark.sum('exporter').sel(importer=plot_order_co), total_ray.sum('exporter').sel(importer=plot_order_co)],
    model_names=["Sharks", "Rays"],
    figsize=(5, 12),
    combined=True,
    ax=ax[0,1]
)
tmp_lab = plot_order_co.Importer.to_numpy()[::-1]
tmp_lab[tmp_lab=="Other Asia, nes"] = 'Taiwan'
ax[0,1].set_yticklabels(tmp_lab)
ax[0,1].set_title("Top consumers")
#ax[0,1].tick_params(axis='y', labelright=True, right=False)
#ax[0,1].tick_params(axis='y', labelleft=False, left=False)
ax[0,1].legend_.remove() 
ax[0,1].set_xlabel('(t)')
ax[0,1].yaxis.set_label_position("right")
ax[0,1].set_ylabel('')
#ax[0,1].set_yticklabels(fontsize=10)
ax[0,1].yaxis.tick_right()

plt.tight_layout()
#plt.subplots_adjust(hspace=.0)
plt.savefig(bf+'/Global/'+'Top_trading_nations.jpg',dpi=300);
# Out:
# /var/folders/0t/qrl_lm21285bvxnv0dg58ycm0000gn/T/ipykernel_85698/644026599.py:70: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# ## RE-cast as per Josh's pie chart plots
#  replace consumers with utilizers
#  for total individuals - use smooth kde distrubtions
#      - add plot for retained above plot for traded in panel A -i.e. split individuals plots into retained sharks and rays AND traded sharks and rays
#      - make b,c,d top 10 or whatever looks good with these as doughnut plots for ray and shark proportions of totals

# %%
total_trade = total_shark_trade+total_ray_trade

# %%
# Grab top N 
N = 10
plot_order_ex = total_trade.sortby(total_trade.mean(('chain','draw','importer')), ascending=False).exporter[:N]
plot_order_im = total_trade.sortby(total_trade.mean(('chain','draw','exporter')), ascending=False).importer[:N]
plot_order_co = trade_spp_tot.sortby(trade_spp_tot.mean(('chain','draw','exporter','species')), ascending=False).importer[:N]

# %%
# Data to locate exporter plot
tmpdata = total_trade.sum('importer').sel(exporter=plot_order_ex)
# Create dataframe for piecharts
piedata = tmpdata.median(('chain','draw')).to_dataframe().reset_index().rename(columns={"": "total_landings"})
piedata['l90'] = tmpdata.quantile(.05,('chain','draw')).values
piedata['l50'] = tmpdata.quantile(.25,('chain','draw')).values
piedata['u50'] = tmpdata.quantile(.75,('chain','draw')).values
piedata['u90'] = tmpdata.quantile(.95,('chain','draw')).values
# Add sharks and rays
piedata['sharks'] = total_shark_trade.sum('importer').sel(exporter=plot_order_ex).mean(('chain','draw')).to_dataframe().reset_index()[""]
piedata['rays'] = total_ray_trade.sum('importer').sel(exporter=plot_order_ex).mean(('chain','draw')).to_dataframe().reset_index()[""]
# Convert to proportions
piedata['shark_prop'] = piedata['sharks']/(piedata['sharks']+piedata['rays'])
piedata['ray_prop'] = piedata['rays']/(piedata['sharks']+piedata['rays'])
# Add location for y plotting
piedata['yloc'] = piedata.index.values[::-1]


# Data to locate importer plot
tmpdata = total_trade.sum('exporter').sel(importer=plot_order_im)
# Create dataframe for piecharts
piedata_im = tmpdata.median(('chain','draw')).to_dataframe().reset_index().rename(columns={"": "total_landings"})
piedata_im['l90'] = tmpdata.quantile(.05,('chain','draw')).values
piedata_im['l50'] = tmpdata.quantile(.25,('chain','draw')).values
piedata_im['u50'] = tmpdata.quantile(.75,('chain','draw')).values
piedata_im['u90'] = tmpdata.quantile(.95,('chain','draw')).values
# Add sharks and rays
piedata_im['sharks'] = total_shark_trade.sum('exporter').sel(importer=plot_order_im).mean(('chain','draw')).to_dataframe().reset_index()[""]
piedata_im['rays'] = total_ray_trade.sum('exporter').sel(importer=plot_order_im).mean(('chain','draw')).to_dataframe().reset_index()[""]
# Convert to proportions
piedata_im['shark_prop'] = piedata_im['sharks']/(piedata_im['sharks']+piedata_im['rays'])
piedata_im['ray_prop'] = piedata_im['rays']/(piedata_im['sharks']+piedata_im['rays'])
# Add location for y plotting
piedata_im['yloc'] = piedata_im.index.values[::-1]


# Data to locate utilizer plot
tmpdata = trade_spp_tot.sum(('exporter','species')).sel(importer=plot_order_co)
# Create dataframe for piecharts
piedata_ut = tmpdata.median(('chain','draw')).to_dataframe().reset_index().rename(columns={"": "total_landings"})
piedata_ut['l90'] = tmpdata.quantile(.05,('chain','draw')).values
piedata_ut['l50'] = tmpdata.quantile(.25,('chain','draw')).values
piedata_ut['u50'] = tmpdata.quantile(.75,('chain','draw')).values
piedata_ut['u90'] = tmpdata.quantile(.95,('chain','draw')).values
# Add sharks and rays
piedata_ut['sharks'] = total_shark.sum('exporter').sel(importer=plot_order_co).mean(('chain','draw')).to_dataframe().reset_index()[""]
piedata_ut['rays'] = total_ray.sum('exporter').sel(importer=plot_order_co).mean(('chain','draw')).to_dataframe().reset_index()[""]
# Convert to proportions
piedata_ut['shark_prop'] = piedata_ut['sharks']/(piedata_ut['sharks']+piedata_ut['rays'])
piedata_ut['ray_prop'] = piedata_ut['rays']/(piedata_ut['sharks']+piedata_ut['rays'])
# Add location for y plotting
piedata_ut['yloc'] = piedata_ut.index.values[::-1]

# %%
def drawPieMarker(xs, ys, ratios, sizes, colors, ax):
    assert sum(ratios) <= 1, 'sum of ratios needs to be < 1'

    markers = []
    previous = 0
    # calculate the points of the pie pieces
    for color, ratio in zip(colors, ratios):
        this = 2 * np.pi * ratio + previous
        x  = [0] + np.cos(np.linspace(previous, this, 10)).tolist() + [0]
        y  = [0] + np.sin(np.linspace(previous, this, 10)).tolist() + [0]
        xy = np.column_stack([x, y])
        previous = this
        markers.append({'marker':xy, 's':np.abs(xy).max()**2*np.array(sizes), 'facecolor':color, 'edgecolor':'black'})

    # scatter each of the pie pieces to create pies
    for marker in markers:
        ax.scatter(xs, ys, **marker, zorder=10)

# %%
fig = plt.figure(figsize=(18, 5))
(lftfig, rtfig1, rtfig2, rtfig3) = fig.subfigures(1,4, width_ratios=(.7,2,2,2))

# - - - - - - - - - - - - - - - Initialize left plot
(lft_top_axs,lft_bot_axs) = lftfig.subplots(2, 1)

# Plot individuals retained
az.plot_dist(EstNsharks/1300000, color="C0", ax=lft_top_axs, label='Sharks')
az.plot_dist(EstNrays/1000000, color="C1", ax=lft_top_axs, label='Rays')
lft_top_axs.set_yticklabels("")
lft_top_axs.set_xticklabels("")
lft_top_axs.set_xlabel('')
lft_top_axs.legend_.remove() 
lft_top_axs.set_title('Landed')

# Plot individuals retained
az.plot_dist(EstNsharks/1300000, color="C0", ax=lft_bot_axs, label='Sharks')
az.plot_dist(EstNrays/1000000, color="C1", ax=lft_bot_axs, label='Rays')
lft_bot_axs.set_xticks((15,20,25))
lft_bot_axs.set_yticklabels("")
lft_bot_axs.set_xlabel('Millions')
lft_bot_axs.set_title('Traded')

# Max x value
topx = 150000

# - - - - - - - - - - - - - - - Initialize next plot
rtfig1_axs = rtfig1.subplots(1, 1)

# Exporters
rtfig1_axs.scatter(x=piedata['total_landings'], y=piedata['yloc'], s=30, facecolor='white', edgecolors='none', zorder=11)
rtfig1_axs.plot((piedata['l90'],piedata['u90']), (piedata['yloc'],piedata['yloc']), c='black', linewidth=2, zorder=9)
rtfig1_axs.plot((piedata['l50'],piedata['u50']), (piedata['yloc'],piedata['yloc']), c='black', linewidth=5, zorder=9)

for xx,yy,xxr,yyr in zip(piedata['total_landings'],piedata['yloc'],piedata['shark_prop'].values,piedata['ray_prop'].values):
    drawPieMarker(xs=xx,
                  ys=yy,
                  ratios=[xxr,yyr],
                  sizes=[400],
                  colors=['blue', 'orange'],
                  ax=rtfig1_axs)

tmp_lab = plot_order_ex.Exporter.to_numpy()[::-1]
tmp_lab[tmp_lab=="Other Asia, nes"] = 'Taiwan'
rtfig1_axs.set_yticks(np.arange(len(tmp_lab)))
rtfig1_axs.set_yticklabels(tmp_lab)
[tk.set_visible(True) for tk in rtfig1_axs.get_yticklabels()]
rtfig1_axs.set_xlabel('(t/yr)')
rtfig1_axs.set_xlim(-500,topx)
rtfig1_axs.set_title('Top exporters')
#rtfig1_axs.legend_.remove() 


# - - - - - - - - - - - - - - - Initialize next plot
rtfig2_axs = rtfig2.subplots(1, 1)

# Importers
rtfig2_axs.scatter(x=piedata_im['total_landings'], y=piedata_im['yloc'], s=30, facecolor='white', edgecolors='none', zorder=11)
rtfig2_axs.plot((piedata_im['l90'],piedata_im['u90']), (piedata_im['yloc'],piedata_im['yloc']), c='black', linewidth=2, zorder=9)
rtfig2_axs.plot((piedata_im['l50'],piedata_im['u50']), (piedata_im['yloc'],piedata_im['yloc']), c='black', linewidth=5, zorder=9)

for xx,yy,xxr,yyr in zip(piedata_im['total_landings'],piedata_im['yloc'],piedata_im['shark_prop'].values,piedata_im['ray_prop'].values):
    drawPieMarker(xs=xx,
                  ys=yy,
                  ratios=[xxr,yyr],
                  sizes=[400],
                  colors=['blue', 'orange'],
                  ax=rtfig2_axs)

tmp_lab = plot_order_im.Importer.to_numpy()[::-1]
tmp_lab[tmp_lab=="Other Asia, nes"] = 'Taiwan'
rtfig2_axs.set_yticks(np.arange(len(tmp_lab)))
rtfig2_axs.set_yticklabels(tmp_lab)
[tk.set_visible(True) for tk in rtfig2_axs.get_yticklabels()]
rtfig2_axs.set_xlabel('(t/yr)')
rtfig2_axs.set_xlim(-500,topx)
rtfig2_axs.set_title('Top importers')

# - - - - - - - - - - - - - - - Initialize next plot
rtfig3_axs = rtfig3.subplots(1, 1)

# Utilizers
rtfig3_axs.scatter(x=piedata_ut['total_landings'], y=piedata_ut['yloc'], s=30, facecolor='white', edgecolors='none', zorder=11)
rtfig3_axs.plot((piedata_ut['l90'],piedata_ut['u90']), (piedata_ut['yloc'],piedata_ut['yloc']), c='black', linewidth=2, zorder=9)
rtfig3_axs.plot((piedata_ut['l50'],piedata_ut['u50']), (piedata_ut['yloc'],piedata_ut['yloc']), c='black', linewidth=5, zorder=9)

for xx,yy,xxr,yyr in zip(piedata_ut['total_landings'],piedata_ut['yloc'],piedata_ut['shark_prop'].values,piedata_ut['ray_prop'].values):
    drawPieMarker(xs=xx,
                  ys=yy,
                  ratios=[xxr,yyr],
                  sizes=[400],
                  colors=['blue', 'orange'],
                  ax=rtfig3_axs)

tmp_lab = piedata_ut.Importer.to_numpy()[::-1]
tmp_lab[tmp_lab=="Other Asia, nes"] = 'Taiwan'
rtfig3_axs.set_yticks(np.arange(len(tmp_lab)))
rtfig3_axs.set_yticklabels(tmp_lab)
[tk.set_visible(True) for tk in rtfig3_axs.get_yticklabels()]
rtfig3_axs.set_xlabel('(t/yr)')
rtfig3_axs.set_xlim(-500,topx)
rtfig3_axs.set_title('Top utilizers')

plt.savefig(bf+'/Global/'+'Top_trading_nations.jpg',dpi=300);

# %% [markdown]
# # Diversity of top 10 exporters vs diversity of top 10 importers
#
# blue shark is so dominant that’s what is currently represented but showing how the rest of the trade is made up of multiple species is a key message. I’ll work to punch this up. I’m thinking also that the diversity really comes through in the imports – exports tend to be dominated by a few key species while imports are more diverse

# %%
# Calculate proportion of catch exported
dom = domestic_spp.sum(('species','importer'))
tot = domestic_spp.sum(('species','importer'))+trade_spp.sum(('species','importer'))
prop_ex = 1-(dom/tot)
prop_ex = prop_ex.sortby(prop_ex.median(('chain','draw')))

# %%
# Plot proportion of trade exported
ax = az.plot_forest(
        prop_ex,
        hdi_prob=0.9,
        combined=True,
        figsize=(8, 12)
        )
ax[0].set(
    title="Export/landings ratio",
    xlabel="Proportion exports",
    ylabel="",
);
for tick in ax[0].get_xticklabels():
    tick.set_rotation(45)

tmp_lab = prop_ex.Exporter.to_numpy()[::-1]
tmp_lab[tmp_lab=="Other Asia, nes"] = 'Taiwan'
ax[0].set_yticklabels(tmp_lab)

plt.savefig(bf+'/Global/'+'AUGM_Proportion_exports.jpg',dpi=300);

# %% [markdown]
# # Jess' comment about foreign vs domestic consumption by species -
#
# Getting at the foreign versus domestic component of consumption, by species, seems important here to support the claims of trade being a key driver of exploitation. Relatedly, it would be interesting to see which species are predominately for export (i.e., > 50% of the species landed is exported).
#
# ### NB: plot of domestic retention (i.e. not exported) plus imports but doing this by species should get at national preferences best.

# %% [markdown]
# ## Observed bits for plotting

# %%
# Grab species level estimates for observed data
Obs_spp_data = np.exp(sdata.drop(columns=['year','year_spp_id','country_spp_id','species_spp_id']
          ).groupby(['country','species']).mean()).rename(columns={"logReported_species_landings": "Reported_landings"})

# Create xarray data of totals by species
Obs_spp_sums = xr.Dataset(Obs_spp_data.groupby(level='species').sum().sort_values(by='Reported_landings', ascending=False))

# Grab taxon level estimates for observed data
Obs_tax_data = np.exp(txdata.drop(columns=['year','year_tax_id','country_tax_id','taxon_tax_id']
          ).groupby(['country','taxon']).mean()).rename(columns={"logReported_taxon_landings": "Reported_landings"})

# Net estimated unreported species-level landings
Net_spp_landings = idata_landings_x.posterior['Latent_landings']-idata_landings_x.posterior['CountrySPP_landings']

# %% [markdown]
# ## Species proporitons in latent landings

# %%
# Select top 10% of traded species
tmp = trade_spp.sum(('exporter','importer')).median(('chain','draw'))
#tmp = idata_landings_x.posterior['Latent_landings'].sum(('exporter')).median(('chain','draw'))
tmp = tmp.sortby(tmp, ascending=False)
sppx_trad = tmp[tmp>np.quantile(tmp,0.90)].species[:15]

late_land = idata_landings_x.posterior['Latent_landings'].sel(species=sppx_trad).sum(('exporter')).rename("")
tmp = late_land.median(('chain','draw')).to_dataframe().reset_index()
tmp.columns = ['species','group','value']
tmp['proportion'] = tmp['value']/sum(tmp['value'])
tmp.sort_values(by='value',ascending=False)
# Out:
#                      species   group          value  proportion
# 0            Prionace glauca  sharks  124459.486891    0.531005
# 1          Squalus acanthias  sharks   18163.991521    0.077496
# 2          Isurus oxyrinchus  sharks   16767.056561    0.071536
# 3   Carcharhinus falciformis  sharks   14964.944269    0.063848
# 6          Alopias pelagicus  sharks   10646.415203    0.045423
# 4         Leucoraja ocellata    rays    9062.832601    0.038666
# 7      Scyliorhinus canicula  sharks    7199.995448    0.030719
# 8               Raja clavata    rays    6464.589367    0.027581
# 5         Leucoraja erinacea    rays    5805.837388    0.024771
# 9         Galeorhinus galeus  sharks    5124.463596    0.021863
# 10          Leucoraja naevus    rays    3761.423224    0.016048
# 13           Sphyrna zygaena  sharks    3653.537803    0.015588
# 14         Mustelus mustelus  sharks    3543.167674    0.015117
# 11            Raja brachyura    rays    2656.407961    0.011334
# 12          Beringraja rhina    rays    2110.776545    0.009006

# %%
trade_spp.sel(importer='BRA').sum(('exporter')).mean(('chain','draw')).to_dataframe().drop(columns=['importer','Importer']).reset_index().groupby('Group').sum()
# Out:
#                                                   species
# Group
# rays    Acroteriobatus annulatusAcroteriobatus blochii...      0.000000
# sharks  Aculeola nigraAlopias pelagicusAlopias superci...  26367.297905

# %%
total_shark_trade.sel(importer='BRA').mean(('chain','draw')).sum()
# Out:
# <xarray.DataArray '' ()>
# array(26367.29790468)
# Coordinates:
#     importer  <U3 'BRA'
#     Importer  object 'Brazil'

# %%
total_shark_trade.sel(importer='ESP').mean(('chain','draw')).sum()
# Out:
# <xarray.DataArray '' ()>
# array(18892.51397982)
# Coordinates:
#     importer  <U3 'ESP'
#     Importer  object 'Spain'

# %%
country_
# Out:
# array(['AGO', 'ARE', 'ARG', 'AUS', 'BEL', 'BGD', 'BLZ', 'BRA', 'CAN',
#        'CHL', 'CHN', 'CMR', 'COL', 'CRI', 'CUB', 'DEU', 'DNK', 'ECU',
#        'ESP', 'FRA', 'GBR', 'GHA', 'GRC', 'HKG', 'IDN', 'IND', 'IRL',
#        'IRN', 'ITA', 'JPN', 'KOR', 'LBY', 'LKA', 'MAR', 'MDG', 'MEX',
#        'MOZ', 'MRT', 'MYS', 'NAM', 'NGA', 'NLD', 'NOR', 'NZL', 'OMN',
#        'PAK', 'PAN', 'PER', 'PHL', 'POL', 'PRT', 'RUS', 'SEN', 'SGP',
#        'SLE', 'SWE', 'THA', 'TTO', 'TUN', 'TWN', 'TZA', 'URY', 'USA',
#        'VEN', 'VUT', 'YEM', 'ZAF'], dtype='<U3')

# %%
total_shark_trade.sel(importer='PRT').mean(('chain','draw')).sum()
# Out:
# <xarray.DataArray '' ()>
# array(27023.85520643)
# Coordinates:
#     importer  <U3 'PRT'
#     Importer  object 'Portugal'

# %%
fdata[(fdata.country_code=='BRA')&(fdata.group!='elasmos')].landed_weight.sum()/len(fdata.year.unique())
# Out:
# 9836.75

# %%
tdata[(tdata.ISOim_j=='BRA')&(fdata.group=='rays')].estimated_live_weight.sum()/len(tdata.year_t.unique())
# Out:
# /var/folders/0t/qrl_lm21285bvxnv0dg58ycm0000gn/T/ipykernel_85698/2758669303.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tdata[(tdata.ISOim_j=='BRA')&(fdata.group=='rays')].estimated_live_weight.sum()/len(tdata.year_t.unique())
# 4478.961731804607

# %%
tdata[(tdata.ISOim_j=='BRA')].estimated_live_weight.sum()/len(tdata.year_t.unique())
# Out:
# 24358.199837804823

# %% [markdown]
# ## Plot top reported and unreported species

# %%
# Select top 10% of traded species
tmp = trade_spp.sum(('exporter','importer')).median(('chain','draw'))
#tmp = idata_landings_x.posterior['Latent_landings'].sum(('exporter')).median(('chain','draw'))
tmp = tmp.sortby(tmp, ascending=False)
sppx_trad = tmp[tmp>np.quantile(tmp,0.90)].species[:15]

# Select reported landings
rep_land = idata_landings_x.posterior['CountrySPP_landings'].sel(species=sppx_trad).sum(('exporter')).rename("")

# Select unreported landings
unrep_land = idata_landings_x.posterior['CountrySPP_Taxonlandings'].sel(species=sppx_trad).sum(('exporter')).rename("")

# Proportion unreported
prop_land = unrep_land/(rep_land+unrep_land)

# Select trade
late_trad = trade_spp.sel(species=sppx_trad).sum(('exporter','importer')).rename("")

# Proporiton of unreported trade
un_trad = late_trad*prop_land

# %%
tmp = rep_land.median(('chain','draw')).to_dataframe().reset_index()
tmp.columns = ['species','group','value']
tmp['proportion'] = tmp['value']/sum(tmp['value'])
tmp.sort_values(by='value',ascending=False)
# Out:
#                      species   group          value  proportion
# 0            Prionace glauca  sharks  111228.516632    0.590433
# 1          Squalus acanthias  sharks   15708.689363    0.083386
# 2          Isurus oxyrinchus  sharks   12259.025089    0.065074
# 6          Alopias pelagicus  sharks    6972.965356    0.037015
# 4         Leucoraja ocellata    rays    6649.037959    0.035295
# 7      Scyliorhinus canicula  sharks    6423.044393    0.034095
# 3   Carcharhinus falciformis  sharks    6164.146383    0.032721
# 8               Raja clavata    rays    5232.507468    0.027776
# 5         Leucoraja erinacea    rays    4456.239928    0.023655
# 9         Galeorhinus galeus  sharks    4124.934650    0.021896
# 10          Leucoraja naevus    rays    3205.899453    0.017018
# 11            Raja brachyura    rays    2300.360563    0.012211
# 14         Mustelus mustelus  sharks    1635.318936    0.008681
# 13           Sphyrna zygaena  sharks    1414.102209    0.007506
# 12          Beringraja rhina    rays     609.822794    0.003237

# %%
# = = = = = Set up plot
_, ax = plt.subplots(1,1,figsize=(8, 5))

# Exporters
az.plot_forest(
    [late_trad, un_trad],
    model_names=["Total", "Unreported"],
    figsize=(5, 12),
    combined=True,
    ax=ax
)
tmp_lab = sppx_trad.to_numpy()[::-1]
#ax.set_xlim(-2000, 25000)
#ax.set_xscale('log')
ax.set_yticklabels(tmp_lab)
ax.set_title("Top species in trade")
#ax.legend(loc="upper left")

ax.set_xlabel('(t)')
plt.savefig(bf+'/Global/'+'Top_traded_species.jpg',dpi=300);

# %% [markdown]
# ####

# %% [markdown]
# ## Plot non-blue shark trade

# %%
# Select top 10% of traded species
tmp = trade_spp.sum(('exporter','importer')).median(('chain','draw'))
#tmp = idata_landings_x.posterior['Latent_landings'].sum(('exporter')).median(('chain','draw'))
tmp = tmp.sortby(tmp, ascending=False)
# Species with more than 100 tonnes traded globally/year
sppx_trad = tmp[tmp>100].species
sppx_trad
# Out:
# <xarray.DataArray 'species' (species: 169)>
# array(['Prionace glauca', 'Squalus acanthias', 'Isurus oxyrinchus',
#        'Carcharhinus falciformis', 'Leucoraja ocellata', 'Leucoraja erinacea',
#        'Alopias pelagicus', 'Scyliorhinus canicula', 'Raja clavata',
#        'Galeorhinus galeus', 'Leucoraja naevus', 'Raja brachyura',
#        'Beringraja rhina', 'Sphyrna zygaena', 'Mustelus mustelus',
#        'Alopias superciliosus', 'Mustelus lenticulatus',
#        'Rhynchobatus australiae', 'Sphyrna lewini', 'Alopias vulpinus',
#        'Dalatias licha', 'Dipturus nasutus', 'Raja montagui',
#        'Rhizoprionodon acutus', 'Scyliorhinus stellaris', 'Mustelus canis',
#        'Himantura uarnak', 'Carcharhinus longimanus', 'Acroteriobatus salalah',
#        'Carcharhinus limbatus', 'Sphyrna mokarran', 'Himantura leoparda',
#        'Galeocerdo cuvier', 'Himantura undulata', 'Mustelus asterias',
#        'Dasyatis pastinaca', 'Dipturus nidarosiensis', 'Mustelus schmitti',
#        'Beringraja binoculata', 'Carcharodon carcharias',
#        'Carcharhinus plumbeus', 'Dipturus innominatus', 'Amblyraja radiata',
#        'Centrophorus squamosus', 'Squalus blainville',
#        'Carcharhinus brachyurus', 'Carcharhinus sorrah', 'Cetorhinus maximus',
#        'Isurus paucus', 'Bathyraja meridionalis', 'Pteroplatytrygon violacea',
#        'Gymnura altavela', 'Squalus megalops', 'Deania calcea',
#        'Carcharhinus brevipinna', 'Squatina argentina',
#        'Carcharhinus dussumieri', 'Rhincodon typus', 'Lamna nasus',
#        'Leucoraja circularis', 'Mobula tarapacana', 'Notorynchus cepedianus',
#        'Bathytoshia lata', 'Carcharhinus leucas', 'Carcharhinus signatus',
#        'Rhizoprionodon oligolinx', 'Hexanchus griseus',
#        'Carcharhinus albimarginatus', 'Leucoraja fullonica',
#        'Rhinoptera marginata', 'Raja microocellata', 'Mobula birostris',
#        'Dipturus oxyrinchus', 'Cephaloscyllium isabellum', 'Rajella bigelowi',
#        'Rhizoprionodon terraenovae', 'Scoliodon laticaudus',
#        'Aetomylaeus maculatus', 'Galeus melastomus', 'Rajella fyllae',
#        'Glaucostegus cemiculus', 'Etmopterus pusillus', 'Raja undulata',
#        'Dipturus batis', 'Myliobatis aquila', 'Eusphyra blochii',
#        'Etmopterus spinax', 'Bathyraja spinicauda', 'Amblyraja georgiana',
#        'Torpedo marmorata', 'Aetobatus narinari', 'Mobula mobular',
#        'Centroscymnus coelolepis', 'Rostroraja alba', 'Rhinoptera javanica',
#        'Centrophorus granulosus', 'Rhynchobatus djiddensis',
#        'Rhynchobatus laevis', 'Pristis zijsron', 'Bathyraja brachyurops',
#        'Hemitrygon akajei', 'Carcharhinus amboinensis', 'Raja asterias',
#        'Torpedo torpedo', 'Heptranchias perlo', 'Carcharhinus altimus',
#        'Raja miraletus', 'Squalus formosus', 'Scymnodon ichiharai',
#        'Deania profundorum', 'Bathytoshia centroura', 'Pristis pristis',
#        'Etmopterus princeps', 'Raja radula', 'Amblyraja hyperborea',
#        'Anoxypristis cuspidata', 'Hypanus americanus', 'Carcharias taurus',
#        'Rajella kukujevi', 'Triaenodon obesus', 'Gymnura poecilura',
#        'Carcharhinus melanopterus', 'Bathyraja eatonii',
#        'Rhizoprionodon longurio', 'Aetomylaeus nichofii', 'Galeus murinus',
#        'Ginglymostoma cirratum', 'Raja polystigma', 'Aetobatus narutobiei',
#        'Malacoraja senta', 'Carcharhinus obscurus', 'Carcharhinus cerdale',
#        'Neoraja iberica', 'Hypanus say', 'Hypanus dipterurus',
#        'Neoraja caerulea', 'Rajella lintea', 'Tetronarce nobiliana',
#        'Sphyrna tiburo', 'Taeniura lymma', 'Scoliodon macrorhynchos',
#        'Myliobatis freminvillei', 'Carcharhinus acronotus',
#        'Beringraja pulchra', 'Pseudocarcharias kamoharai', 'Mustelus mosis',
#        'Mustelus manazo', 'Oxynotus centrina', 'Pristis pectinata',
#        'Aetomylaeus vespertilio', 'Hypanus sabinus', 'Taeniurops grabatus',
#        'Rhinobatos punctifer', 'Platyrhina tangi', 'Gymnura zonura',
#        'Aetomylaeus bovinus', 'Nebrius ferrugineus', 'Carcharhinus sealei',
#        'Urogymnus asperrimus', 'Orectolobus leptolineatus',
#        'Etmopterus lucifer', 'Sphyrna gilberti', 'Dipturus chilensis',
#        'Mobula eregoodoo', 'Aetobatus flagellum', 'Hemitriakis japanica',
#        'Carcharhinus macloti', 'Loxodon macrorhinus', 'Rhinobatos rhinobatos'],
#       dtype='<U33')
# Coordinates:
#   * species  (species) <U33 'Prionace glauca' ... 'Rhinobatos rhinobatos'
#     Group    (species) object 'sharks' 'sharks' 'sharks' ... 'sharks' 'rays'

# %%
# Select top 10% of traded species
tmp = trade_spp.sum(('exporter','importer')).median(('chain','draw'))
#tmp = idata_landings_x.posterior['Latent_landings'].sum(('exporter')).median(('chain','draw'))
tmp = tmp.sortby(tmp, ascending=False)
# Species with more than 100 tonnes traded globally/year
sppx_trad = tmp[tmp>100].species
# blue shark trade
bs_trad = sppx_trad[0]
sppx_trad = sppx_trad[1:]

# Select reported landings
rep_land = idata_landings_x.posterior['CountrySPP_landings'].sel(species=sppx_trad).sum(('exporter')).rename("")
rep_land_bs = idata_landings_x.posterior['CountrySPP_landings'].sel(species=bs_trad).sum(('exporter')).rename("")

# Select unreported landings
unrep_land = idata_landings_x.posterior['CountrySPP_Taxonlandings'].sel(species=sppx_trad).sum(('exporter')).rename("")
unrep_land_bs = idata_landings_x.posterior['CountrySPP_Taxonlandings'].sel(species=bs_trad).sum(('exporter')).rename("")

# Proportion unreported
prop_land = unrep_land/(rep_land+unrep_land)
prop_land_bs = unrep_land_bs/(rep_land_bs+unrep_land_bs)

# Select trade
late_trad = trade_spp.sel(species=sppx_trad).sum(('exporter','importer')).rename("")
late_trad_bs = trade_spp.sel(species=bs_trad).sum(('exporter','importer')).rename("")

# Proporiton of unreported trade
un_trad = late_trad*prop_land
un_trad_bs = late_trad_bs*prop_land_bs

# %% [markdown]
# ### Blue shark proportion of total trade

# %%
# Blue shark proportion of total trade
bs_prop = late_trad_bs/(late_trad_bs+late_trad.sum('species'))
np.quantile(bs_prop,(0.5, 0.05, 0.95))
# Out:
# array([0.33729266, 0.24274736, 0.41811478])

# %%
# = = = = = Set up plot
_, ax = plt.subplots(1,1,figsize=(8, 17))

# Exporters
az.plot_forest(
    [late_trad, un_trad],
    model_names=["Total", "Unreported"],
    figsize=(5, 12),
    combined=True,
    ax=ax
)
tmp_lab = sppx_trad.to_numpy()[::-1]
#ax.set_xlim(-2000, 25000)
#ax.set_xscale('log')
ax.set_yticklabels(tmp_lab)
ax.set_title("Top species in trade")
#ax.legend(loc="upper left")

ax.set_xlabel('(t)')
#lt.savefig(bf+'/Global/'+'Top_traded_species.jpg',dpi=300);
# Out:
# Text(0.5, 0, '(t)')

# %% [markdown]
# ## Trade by group

# %%
hdata[hdata.species_binomial=='Scyliorhinus canicula']
# Out:
#               Class     Superorder              Order          Family  \
# 852  Elasmobranchii  Selachimorpha  Carcharhiniformes  Scyliorhinidae
#
#             Genus       species_binomial PrimaryHabitat  DepthMin_m_text  \
# 852  Scyliorhinus  Scyliorhinus canicula        Coastal              1.0
#
#      DepthMax_m_text  MaxLinearDimension BodySizeClass EcomorphotypeLevel1
# 852            800.0               100.0         small          probenthic

# %%
hdata[(hdata.PrimaryHabitat=='Pelagic')&(hdata.Superorder=='Batoidea')].species_binomial.values
# Out:
# array(['Pteroplatytrygon violacea', 'Mobula alfredi', 'Mobula japanica',
#        'Mobula birostris', 'Mobula eregoodoo', 'Mobula hypostoma',
#        'Mobula kuhlii', 'Mobula mobular', 'Mobula munkiana',
#        'Mobula tarapacana', 'Mobula thurstoni'], dtype=object)

# %%
hdata['Group'] = hdata.Superorder
maskx = hdata.Group=='Batoidea'
hdata.loc[maskx,'Group'] = 'Rays'
maskx = hdata.Group=='Selachimorpha'
hdata.loc[maskx,'Group'] = 'Sharks'
hdata['HabitatGroup'] = np.array([x+' '+y for x,y in zip(hdata.PrimaryHabitat, hdata.Group)])
Habitat = hdata.HabitatGroup[match(species_,list(hdata.species_binomial))].to_numpy()

# %% [markdown]
# ## Plot traded vs CITES and ICUN status

# %%
# Download CITES status
cdata = pd.read_csv(bd+'cites_listing_2013.csv')
#cdata['CITES'] = np.array([s.split('(')[0] for s in list(cdata.CITES_YEAR.values.astype(str))])
#cdata['Year'] = np.array([s.split('(')[1][:-1] for s in list(cdata.CITES_YEAR.values.astype(str))]).astype(int)
CITES = np.array(['Not listed']*len(trade_spp.species))
tmp = match(list(cdata.Species.values),list(trade_spp.species.values))
CITES[np.array(tmp[tmp!=None]).astype(int)] = 'Listed'

# %%
# Download redlist status
rdata = pd.read_excel(bd+'SHARKS_species_current_status_full_list.xlsx',header=0).sort_values(by='genus').reset_index()
# Full species name
rdata['species_'] = rdata[['genus','species']].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)
# Grab IUCN status
tmp = rdata.Rlcategory[match(species_,list(rdata.species_))].to_numpy()
# Make endangered and critically endangered 
IUCN = np.array(['Not','Endangered'])[((tmp=='CR') + (tmp=='EN'))*1]
# Make all categories
IUCN_all = tmp

# %%
# Total landings in all species
tot_land = idata_landings_x.posterior['Latent_landings'].sum('exporter').rename("").assign_coords({"CITES": ("species", CITES), "IUCN": ("species", IUCN)})
mu_tot_land = tot_land.median(('chain','draw')).to_dataframe(name='Landings').reset_index()

# Total trade in all species
tot_trade = trade_spp.sum(('exporter','importer')).rename("").assign_coords({"CITES": ("species", CITES),"IUCN": ("species", IUCN)})
mu_tot_trade = tot_trade.median(('chain','draw')).to_dataframe(name='Exports').reset_index()

# merge dataframes
mu_tot = mu_tot_land.merge(mu_tot_trade)

# Calculate sum of squares to 1:1 to determine level of domestic consumption
mu_tot['Exports/Landings'] = mu_tot.Exports/mu_tot.Landings

# Create column for boxplots of SSE
mu_tot['Listing'] = np.array(['Not listed']*len(mu_tot['IUCN']))
mu_tot.loc[(mu_tot.CITES=='Listed')&(mu_tot.IUCN=='Endangered'),'Listing'] = 'Both'
mu_tot.loc[(mu_tot.CITES!='Listed')&(mu_tot.IUCN=='Endangered'),'Listing'] = 'Endangered'
mu_tot.loc[(mu_tot.CITES=='Listed')&(mu_tot.IUCN!='Endangered'),'Listing'] = 'CITES listed'

# Cut to >100 t
maskx = (mu_tot.Exports>100) & (mu_tot.Landings>100)
# Store spp >100t
spp_100 = species_[maskx]
mu_tot = mu_tot.loc[maskx]

# %% [markdown]
# ## Effects model

# %%
# Response
Eprop = (mu_tot['Exports/Landings']*100).astype(int)
Eprop[Eprop>100] = 100
# IUCN
IUCN_,Ii = indexall(mu_tot.IUCN)
# CITES
CITES_,Ic = indexall(mu_tot.CITES)
# Coordinates
COORDS = {'cites':CITES_, 'iucn':IUCN_, "observation": mu_tot.index.values}

# %%
with pm.Model(coords=COORDS) as iucn_direct_model:

    # Intercept
    Avg_prop = pm.Normal('Avg_prop', 0, 1.5)
    # CITES direct effect
    b_cites = pm.Normal('CITES', 0, 1.5)
    # IUCN direct effect
    b_iucn = pm.Normal('IUCN', 0, 1.5)

    # Linear model
    p_listing = pm.Deterministic('p_listing', pm.math.invlogit(Avg_prop+b_cites*Ic+b_iucn*Ii), dims="observation")

    # Likelihood
    pm.Binomial('Yi', n=100, p=p_listing, observed=Eprop, dims="observation")

    # Average direct IUCN effect on probability scale
    iucn_direct = pm.Deterministic('iucn_direct', pm.math.invlogit(Avg_prop)-pm.math.invlogit(Avg_prop+b_iucn))
    # Average direct CITES effect on probability scale
    cites_direct = pm.Deterministic('cites_direct', pm.math.invlogit(Avg_prop)-pm.math.invlogit(Avg_prop+b_cites))

# %%
with iucn_direct_model:
    iucn_direct_idata = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [Avg_prop, CITES, IUCN]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:00&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1 seconds.

# %%
with pm.Model(coords=COORDS) as iucn_total_model:

    # Intercept
    Avg_prop = pm.Normal('Avg_prop', 0, 1.5)
    # IUCN total effect
    b_iucn = pm.Normal('IUCN', 0, 1.5)

    # Linear model
    p_listing = pm.Deterministic('p_listing', pm.math.invlogit(Avg_prop+b_iucn*Ii), dims="observation")

    # Likelihood
    pm.Binomial('Yi', n=100, p=p_listing, observed=Eprop, dims="observation")

    # Average total IUCN effect on probability scale
    iucn_total = pm.Deterministic('iucn_total', pm.math.invlogit(Avg_prop)-pm.math.invlogit(Avg_prop+b_iucn))

# %%
with iucn_total_model:
    iucn_total_idata = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [Avg_prop, IUCN]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:00&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1 seconds.

# %%
pm.summary(iucn_total_idata, var_names=['Avg_prop', 'IUCN', 'iucn_total'])
# Out:
#              mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# Avg_prop    0.089  0.019   0.053    0.126      0.000    0.000    2197.0
# IUCN       -0.844  0.034  -0.907   -0.781      0.001    0.001    1995.0
# iucn_total  0.202  0.008   0.188    0.217      0.000    0.000    1946.0
#
#             ess_tail  r_hat
# Avg_prop      2676.0    1.0
# IUCN          2191.0    1.0
# iucn_total    2012.0    1.0

# %%
pm.summary(iucn_direct_idata, var_names=['Avg_prop','CITES', 'IUCN','iucn_direct','cites_direct'])
# Out:
#                mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# Avg_prop      0.105  0.020   0.069    0.142      0.000    0.000    2706.0
# CITES        -0.579  0.068  -0.700   -0.450      0.001    0.001    3721.0
# IUCN         -0.769  0.036  -0.839   -0.704      0.001    0.000    2600.0
# iucn_direct   0.186  0.008   0.171    0.202      0.000    0.000    2549.0
# cites_direct  0.142  0.016   0.113    0.172      0.000    0.000    3722.0
#
#               ess_tail  r_hat
# Avg_prop        2799.0    1.0
# CITES           2836.0    1.0
# IUCN            2624.0    1.0
# iucn_direct     2407.0    1.0
# cites_direct    2835.0    1.0

# %%
# Calculate effect sizes
IUCN_direct = iucn_direct_idata.posterior['iucn_direct']*-1
CITES_direct = iucn_direct_idata.posterior['cites_direct']*-1
IUCN_total = iucn_total_idata.posterior['iucn_total']*-1
IUCN_indirect = IUCN_total-IUCN_direct

list_effects = pd.DataFrame({'IUCN indirect':IUCN_indirect.to_numpy().flatten(),
    'IUCN direct':IUCN_direct.to_numpy().flatten(), 
                             'IUCN total':IUCN_total.to_numpy().flatten(), 
                             'CITES direct':CITES_direct.to_numpy().flatten()}).melt()

# %%
# Set up plot
sns.set_theme(style="ticks", palette="hls")

#fig, axs = plt.subplots(ncols=2)
fig = plt.figure(figsize=(10,5))
ax0 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

# -------------------------- Plot CITES Status
g0 = sns.scatterplot(
    data=mu_tot,
    x="Landings", y="Exports",
    hue="Listing",
    palette=('lightgrey','red','black','blue'),
    edgecolor='black', linewidth=.5,
    legend=None,
    ax=ax0
)
g0.set(xscale="log", yscale="log", xlim=(90, None), ylim=(90, None))
g0.xaxis.grid(True, "minor", linewidth=.25)
g0.yaxis.grid(True, "minor", linewidth=.25)
# Add 1:1
ax0.plot((100,10e5), (100,10e5), color='grey', linestyle=':', zorder=10)


# iterate through each axes and increase the linewidth and add a color
ax0.patch.set_linewidth(.5)
ax0.patch.set_edgecolor('black')
ax2.patch.set_linewidth(.5)
ax2.patch.set_edgecolor('black')

g2 = sns.boxplot(data=list_effects, x="value", y="variable", 
                 #color='#FFFFFF00',
                 palette=('#87cefa','#006db0','#000080','grey'),
                 linewidth=.75, showfliers = False,  ax=ax2)
[patch.set(facecolor='grey', edgecolor='black', alpha=0.3) for patch in g2.patches] 
#sns.stripplot(data=list_effects, x="value", y="variable", palette=('#87cefa','#006db0','#000080','grey'), 
#            edgecolor='black', linewidth=.5, zorder=1, ax=ax2)
ax2.yaxis.set_label_position("right")
#ax2.set_yticklabels(['Not listed', 'CITES listed (c. 2013)', 'Endangered (c. 2020)', 'Both'])
ax2.set_ylabel('')
ax2.set_xlabel('Export probabtility effect')
ax2.yaxis.tick_right()
plt.axvline(x=0,color='grey', linestyle=':', zorder=10)

plt.tight_layout()
plt.savefig(bf+'/Global/'+'Landings_vs_trade_CITES_IUCN.jpg',dpi=300);
# Out:
# /var/folders/0t/qrl_lm21285bvxnv0dg58ycm0000gn/T/ipykernel_85698/961842320.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   g2 = sns.boxplot(data=list_effects, x="value", y="variable",
# /var/folders/0t/qrl_lm21285bvxnv0dg58ycm0000gn/T/ipykernel_85698/961842320.py:46: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
mu_tot.Listing
# Out:
# 5      Not listed
# 8      Endangered
# 10     Endangered
# 11     Not listed
# 14     Endangered
#           ...
# 661    Not listed
# 669    Not listed
# 670    Not listed
# 671    Not listed
# 692    Not listed
# Name: Listing, Length: 164, dtype: object

# %%
def label_point(x, y, val, ax, sz=10):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x']+.02, point['y'], str(point['val']), fontsize=sz)

# Set up plot
sns.set_theme(style="ticks", palette="hls")

#fig, axs = plt.subplots(ncols=2)
fig = plt.figure(figsize=(10,10))
ax0 = fig.add_subplot(111)
#ax2 = fig.add_subplot(122)

# -------------------------- Plot CITES Status
g0 = sns.scatterplot(
    data=mu_tot,
    x="Landings", y="Exports",
    hue="Listing",
    palette=('lightgrey','red','black','blue'),
    edgecolor='black', linewidth=.5,
    legend=None,
    ax=ax0
)
g0.set(xscale="log", yscale="log", xlim=(90, None), ylim=(90, None))
g0.xaxis.grid(True, "minor", linewidth=.25)
g0.yaxis.grid(True, "minor", linewidth=.25)
# Add 1:1
ax0.plot((100,10e5), (100,10e5), color='grey', linestyle=':', zorder=10)

indx = mu_tot.Listing!='Not listed'
label_point(mu_tot.Landings[indx], mu_tot.Exports[indx], mu_tot.species[indx], ax=g0)

# iterate through each axes and increase the linewidth and add a color
ax0.patch.set_linewidth(.5)
ax0.patch.set_edgecolor('black')

plt.tight_layout()
plt.savefig(bf+'/Global/'+'Landings_vs_trade_CITES_IUCN_labels.jpg',dpi=300);
# Out:
# /var/folders/0t/qrl_lm21285bvxnv0dg58ycm0000gn/T/ipykernel_85698/609543978.py:37: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# ## figure 2
#  - Remove blue shark if needed above?
#  - Add 5th category for IUCN c. 2013
#  - labels on key species in panel a)
#
# - panel B = causal effect of CITES c2013 and IUCN c2013(ish) on P(exports/Landings)

# %% [markdown]
# ## Plot of percent listed exports per country

# %%
# Select top 10 trading countires
tmp = trade_spp.sum(('species','importer')).median(('chain','draw'))
tmp = tmp.sortby(tmp, ascending=False)
cou_ex = tmp[tmp>np.quantile(tmp,0.60)].exporter[:10]

tmp = trade_spp.sum(('species','exporter')).median(('chain','draw'))
tmp = tmp.sortby(tmp, ascending=False)
cou_im = tmp[tmp>np.quantile(tmp,0.60)].importer[:10]

# Grab countires
trade_cou = np.unique(list(cou_im.values)+list(cou_ex.values))

# %%
# Exports
spp_exports = trade_spp.sel(exporter=trade_cou).sum(('importer')).rename("").assign_coords({"CITES": ("species", CITES)})
listed_exports = spp_exports[:,:,:,spp_exports.CITES=='Listed']
unlisted_exports = spp_exports[:,:,:,spp_exports.CITES!='Listed']
prop_listed_exports = listed_exports.sum('species')/spp_exports.sum('species')

# Imports
spp_imports = trade_spp.sel(importer=trade_cou).sum(('exporter')).rename("").assign_coords({"CITES": ("species", CITES)})
listed_imports = spp_imports[:,:,spp_imports.CITES=='Listed',:]
unlisted_imports = spp_imports[:,:,spp_imports.CITES!='Listed',:]
prop_listed_imports = listed_imports.sum('species')/spp_imports.sum('species')

# %%
plot_order_ex = prop_listed_exports.sortby(prop_listed_exports.sum(('chain','draw')), ascending=False).exporter
plot_order_im = prop_listed_imports.sortby(prop_listed_imports.sum(('chain','draw')), ascending=False).importer

# %%
# = = = = = Set up plot
_, ax = plt.subplots(1,2,figsize=(7, 5))

# Plot proportion of listed trade exported
az.plot_forest(
        prop_listed_exports.sel(exporter=plot_order_ex),
        hdi_prob=0.9,
        combined=True,
        figsize=(7, 10),
        ax=ax[0]
        )
ax[0].set(
    title="Exporters",
    xlabel="Proportion CITES-listed",
    ylabel="",
);
for tick in ax[0].get_xticklabels():
    tick.set_rotation(45)

tmp_lab = plot_order_ex.Exporter.to_numpy()[::-1]
tmp_lab[tmp_lab=="Other Asia, nes"] = 'Taiwan'
ax[0].set_yticklabels(tmp_lab);


# Plot proportion of listed trade imported
az.plot_forest(
        prop_listed_imports.sel(importer=plot_order_im),
        hdi_prob=0.9,
        combined=True,
        figsize=(7, 10),
        ax=ax[1]
        )
ax[1].set(
    title="Importers",
    xlabel="Proportion CITES-listed",
    ylabel="",
);
for tick in ax[1].get_xticklabels():
    tick.set_rotation(45)

tmp_lab = plot_order_im.Importer.to_numpy()[::-1]
tmp_lab[tmp_lab=="Other Asia, nes"] = 'Taiwan'
ax[1].set_yticklabels(tmp_lab);

plt.tight_layout()
plt.savefig(bf+'/Global/'+'CITES_Trade_props.jpg',dpi=300);
# Out:
# /var/folders/0t/qrl_lm21285bvxnv0dg58ycm0000gn/T/ipykernel_85698/4142186538.py:45: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
# Exports
spp_exports = (trade_spp.sel(exporter=plot_order_ex).sum(('importer'))
               .rename("").assign_coords({"IUCN": ("species", IUCN)})
               .assign_coords({"Habitat": ("species", Habitat)})
               .assign_coords({"CITES": ("species", CITES)})
              )
tmp_ex = (spp_exports.to_dataframe(name='trade').reset_index()
          .groupby(['Exporter','IUCN','chain','draw']).sum()
          .reset_index().drop(columns=['exporter','Group','species'])
         )
# Imports
spp_imports = trade_spp.sel(importer=plot_order_im).sum(('exporter')).rename("").assign_coords({"IUCN": ("species", IUCN)}).assign_coords({"Habitat": ("species", Habitat)}).assign_coords({"CITES": ("species", CITES)})
tmp_im = spp_imports.to_dataframe(name='trade').reset_index().groupby(['Importer','IUCN','chain','draw']).sum().reset_index().drop(columns=['importer','Group','species'])
tmp_im.Importer.loc[tmp_im.Importer=='Rep. of Korea'] = 'South Korea'
plot_order_imx = plot_order_im
maskx = plot_order_imx.Importer=='Rep. of Korea'
plot_order_imx.Importer.loc[maskx] = 'South Korea'
# Out:
# /var/folders/0t/qrl_lm21285bvxnv0dg58ycm0000gn/T/ipykernel_85698/2450792950.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_im.Importer.loc[tmp_im.Importer=='Rep. of Korea'] = 'South Korea'

# %%
# Order for IUCN categories
cat_ord = ['CR', 'EN', 'VU', 'NT', 'LC', 'DD']
# Order for Habitats

# %%
tmp_im
# Out:
#      Importer        IUCN  chain  draw  \
# 0      Brazil  Endangered      0     0
# 1      Brazil  Endangered      0     1
# 2      Brazil  Endangered      0     2
# 3      Brazil  Endangered      0     3
# 4      Brazil  Endangered      0     4
# ...       ...         ...    ...   ...
# 3995  Uruguay         Not      3    45
# 3996  Uruguay         Not      3    46
# 3997  Uruguay         Not      3    47
# 3998  Uruguay         Not      3    48
# 3999  Uruguay         Not      3    49
#
#                                                 Habitat  \
# 0     Coastal RaysCoastal RaysCoastal RaysCoastal Ra...
# 1     Coastal RaysCoastal RaysCoastal RaysCoastal Ra...
# 2     Coastal RaysCoastal RaysCoastal RaysCoastal Ra...
# 3     Coastal RaysCoastal RaysCoastal RaysCoastal Ra...
# 4     Coastal RaysCoastal RaysCoastal RaysCoastal Ra...
# ...                                                 ...
# 3995  Coastal RaysCoastal RaysCoastal RaysCoastal Ra...
# 3996  Coastal RaysCoastal RaysCoastal RaysCoastal Ra...
# 3997  Coastal RaysCoastal RaysCoastal RaysCoastal Ra...
# 3998  Coastal RaysCoastal RaysCoastal RaysCoastal Ra...
# 3999  Coastal RaysCoastal RaysCoastal RaysCoastal Ra...
#
#                                                   CITES         trade
# 0     Not listedNot listedNot listedNot listedNot li...   8535.519979
# 1     Not listedNot listedNot listedNot listedNot li...   8227.726215
# 2     Not listedNot listedNot listedNot listedNot li...  13907.631309
# 3     Not listedNot listedNot listedNot listedNot li...   5363.237072
# 4     Not listedNot listedNot listedNot listedNot li...   7925.436121
# ...                                                 ...           ...
# 3995  Not listedNot listedNot listedNot listedNot li...   5506.299058
# 3996  Not listedNot listedNot listedNot listedNot li...   6924.872447
# 3997  Not listedNot listedNot listedNot listedNot li...   4113.567704
# 3998  Not listedNot listedNot listedNot listedNot li...   8747.979959
# 3999  Not listedNot listedNot listedNot listedNot li...   2501.850833
#
# [4000 rows x 7 columns]

# %%
plot_order_imx.Importer.values
# Out:
# array(['Taiwan', 'Argentina', 'New Zealand', 'Indonesia', 'USA',
#        'Singapore', 'Uruguay', 'Thailand', 'Spain', 'China', 'Portugal',
#        'Japan', 'South Korea', 'Brazil', 'France', 'Italy'], dtype=object)

# %%
"""
# = = = = = Set up plot
_, ax = plt.subplots(1,1,figsize=(10, 5))
# Set colour pallette
sns.set_theme(style="ticks", palette="rocket")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="Importer", y="trade",
            hue="IUCN", 
            hue_order = cat_ord,
            palette=['#35193e', '#ad1759', '#e13342', '#f37651', 'lightgrey', 'white'],
            data=tmp_im,
            showfliers=False,
            order=plot_order_imx.Importer.values,
           ax=ax).set(
    xlabel='', 
    ylabel='Imports (t)'
)
# Grab ylims
ylimx = ax.get_ylim()
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.savefig(bf+'/Global/'+'Imports_vs_IUCN.jpg',dpi=300);
"""
# Out:
# '\n# = = = = = Set up plot\n_, ax = plt.subplots(1,1,figsize=(10, 5))\n# Set colour pallette\nsns.set_theme(style="ticks", palette="rocket")\n\n# Draw a nested boxplot to show bills by day and time\nsns.boxplot(x="Importer", y="trade",\n            hue="IUCN", \n            hue_order = cat_ord,\n            palette=[\'#35193e\', \'#ad1759\', \'#e13342\', \'#f37651\', \'lightgrey\', \'white\'],\n            data=tmp_im,\n            showfliers=False,\n            order=plot_order_imx.Importer.values,\n           ax=ax).set(\n    xlabel=\'\', \n    ylabel=\'Imports (t)\'\n)\n# Grab ylims\nylimx = ax.get_ylim()\nax.set_xticklabels(ax.get_xticklabels(), rotation=45)\nplt.savefig(bf+\'/Global/\'+\'Imports_vs_IUCN.jpg\',dpi=300);\n'

# %%
"""
N = 4
# = = = = = Set up plot
_, ax = plt.subplots(1,N,figsize=(14, 5))

# Keep track of outputs
out = []

for i in range(N):
    # Look at major imports to Korea and Brazil
    coux = list(plot_order_im.to_numpy())[i]
    # Pick top imports
    tmp = spp_imports.sel(importer=coux).sortby(spp_imports.sel(importer=coux).mean(('chain','draw')), ascending=False)
    plot_order_x = tmp.species[:10]
    plot_IUCN_x = tmp.IUCN[:10]
    # IUCN colours per species
    coulx = np.array(['#35193e', '#ad1759', '#e13342', '#f37651', 'lightgrey', 'black'])[np.array([cat_ord.index(x) for x in plot_IUCN_x])]
    
    tmp = spp_imports.sel(importer=coux,species=plot_order_x)
    out += [tmp]
    az.plot_forest([tmp[:,:,i] for i in range(len(plot_order_x))],
                        hdi_prob=0.9,
                        kind='forestplot',
                        figsize=(5, 5),
                        combined=True,
                        colors=list(coulx),
                        legend=False,
                        ax = ax[i] 
                       )
    ax[i].set(
        title=coux+" preferences",
        xlabel="Imports (t)",
        ylabel="",
    );
    
    for tick in ax[i].get_xticklabels():
        tick.set_rotation(45)
    tmp_lab = tmp.species.values[::-1]
    ax[i].set_yticklabels(tmp_lab)
plt.savefig(bf+'/Global/'+'Import_spp_IUCN.jpg',dpi=300);
"""
# Out:
# '\nN = 4\n# = = = = = Set up plot\n_, ax = plt.subplots(1,N,figsize=(14, 5))\n\n# Keep track of outputs\nout = []\n\nfor i in range(N):\n    # Look at major imports to Korea and Brazil\n    coux = list(plot_order_im.to_numpy())[i]\n    # Pick top imports\n    tmp = spp_imports.sel(importer=coux).sortby(spp_imports.sel(importer=coux).mean((\'chain\',\'draw\')), ascending=False)\n    plot_order_x = tmp.species[:10]\n    plot_IUCN_x = tmp.IUCN[:10]\n    # IUCN colours per species\n    coulx = np.array([\'#35193e\', \'#ad1759\', \'#e13342\', \'#f37651\', \'lightgrey\', \'black\'])[np.array([cat_ord.index(x) for x in plot_IUCN_x])]\n    \n    tmp = spp_imports.sel(importer=coux,species=plot_order_x)\n    out += [tmp]\n    az.plot_forest([tmp[:,:,i] for i in range(len(plot_order_x))],\n                        hdi_prob=0.9,\n                        kind=\'forestplot\',\n                        figsize=(5, 5),\n                        combined=True,\n                        colors=list(coulx),\n                        legend=False,\n                        ax = ax[i] \n                       )\n    ax[i].set(\n        title=coux+" preferences",\n        xlabel="Imports (t)",\n        ylabel="",\n    );\n    \n    for tick in ax[i].get_xticklabels():\n        tick.set_rotation(45)\n    tmp_lab = tmp.species.values[::-1]\n    ax[i].set_yticklabels(tmp_lab)\nplt.savefig(bf+\'/Global/\'+\'Import_spp_IUCN.jpg\',dpi=300);\n'

# %%
[pm.summary(o.rename(c+' ')) for o,c in zip(out,plot_order_im.to_numpy())]
# Out:
# []

# %%
"""
# = = = = = Set up plot
_, ax = plt.subplots(1,1,figsize=(10, 5))

# Set colour pallette
sns.set_theme(style="ticks", palette="rocket")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="Exporter", y="trade",
            hue="IUCN", 
            hue_order = cat_ord,
            palette=['#35193e', '#ad1759', '#e13342', '#f37651', 'lightgrey', 'white'],
            data=tmp_ex,
            showfliers=False,
            order=plot_order_ex.Exporter.values,
           ax=ax).set(
    xlabel='', 
    ylabel='Exports (t)',
    ylim=ylimx
)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.savefig(bf+'/Global/'+'Exports_vs_IUCN.jpg',dpi=300);
"""
# Out:
# '\n# = = = = = Set up plot\n_, ax = plt.subplots(1,1,figsize=(10, 5))\n\n# Set colour pallette\nsns.set_theme(style="ticks", palette="rocket")\n\n# Draw a nested boxplot to show bills by day and time\nsns.boxplot(x="Exporter", y="trade",\n            hue="IUCN", \n            hue_order = cat_ord,\n            palette=[\'#35193e\', \'#ad1759\', \'#e13342\', \'#f37651\', \'lightgrey\', \'white\'],\n            data=tmp_ex,\n            showfliers=False,\n            order=plot_order_ex.Exporter.values,\n           ax=ax).set(\n    xlabel=\'\', \n    ylabel=\'Exports (t)\',\n    ylim=ylimx\n)\nax.set_xticklabels(ax.get_xticklabels(), rotation=45)\nplt.savefig(bf+\'/Global/\'+\'Exports_vs_IUCN.jpg\',dpi=300);\n'

# %%
plot_order_exx = plot_order_ex.copy()
plot_order_exx.Exporter.loc[plot_order_exx.Exporter=='Other Asia, nes'] = 'Taiwan'

# %%
np.unique(spp_exports.Habitat)
# Out:
# array(['Coastal Rays', 'Coastal Sharks', 'Deepwater Rays',
#        'Deepwater Sharks', 'Freshwater Rays', 'Pelagic Rays',
#        'Pelagic Sharks'], dtype=object)

# %%
# Original subset of countries for species exports
#spp_exports = trade_spp.sel(exporter=plot_order_ex).sum(('importer')).rename("").assign_coords({"IUCN": ("species", IUCN)}).assign_coords({"Habitat": ("species", Habitat)}).assign_coords({"CITES": ("species", CITES)})
# All countries
spp_exports = trade_spp.sum(('importer')).rename("").assign_coords({"IUCN": ("species", IUCN)}).assign_coords({"Habitat": ("species", Habitat)}).assign_coords({"CITES": ("species", CITES)})

# %%
tmp_exH = (spp_exports.drop_sel(species='Prionace glauca')
           .to_dataframe(name='trade').reset_index()
           .groupby(['Exporter','Habitat','chain','draw']).sum()
           .reset_index().drop(columns=['exporter','Group','species'])

          )
# = = = = = Set up plot
_, ax = plt.subplots(1,1,figsize=(10, 6))

# Set colour pallette
sns.set_theme(style="ticks", palette="hls")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="Exporter", y="trade",
            hue="Habitat", 
            #hue_order = cat_ord,
            palette=['#d2b48c', '#654321', '#778899','#000000', '#FFFFFF', '#add8e6','#00008b'],
            saturation=1,
            data=tmp_exH,
            showfliers=False,
            order=plot_order_ex.Exporter.values,
            ax=ax, 
            boxprops=dict(alpha=.7)
           ).set(
    xlabel='', 
    ylabel='Exports (t)',
)

ax.set_xticklabels(plot_order_exx.Exporter.values, rotation=45)
plt.savefig(bf+'/Global/'+'Exports_vs_Habitat.jpg',dpi=300);
# Out:
# /var/folders/0t/qrl_lm21285bvxnv0dg58ycm0000gn/T/ipykernel_85698/67019290.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(plot_order_exx.Exporter.values, rotation=45)

# %%
trade_noBS = (spp_exports.drop_sel(species='Prionace glauca')
           .to_dataframe(name='trade').reset_index()
             .drop(columns=['IUCN','CITES','Group'])
)
trade_HAB = trade_noBS.drop(columns=['exporter','species','Exporter']).groupby(['Habitat','chain','draw']).sum().reset_index()

# %%
trade_HAB
# Out:
#              Habitat  chain  draw          trade
# 0       Coastal Rays      0     0  212668.311977
# 1       Coastal Rays      0     1  132389.085102
# 2       Coastal Rays      0     2  150441.392509
# 3       Coastal Rays      0     3  159012.723244
# 4       Coastal Rays      0     4  147115.762700
# ...              ...    ...   ...            ...
# 1395  Pelagic Sharks      3    45   44271.999615
# 1396  Pelagic Sharks      3    46   41149.235012
# 1397  Pelagic Sharks      3    47   75225.867375
# 1398  Pelagic Sharks      3    48   52834.242286
# 1399  Pelagic Sharks      3    49   62601.396127
#
# [1400 rows x 4 columns]

# %%
# Calculate order by habtiat group
plot_order_habitat = ((spp_exports.drop_sel(species='Prionace glauca')
            .mean(('chain','draw','exporter')).to_dataframe(name='trade').reset_index()
            .groupby(['Habitat']).sum()).reset_index().drop(columns=['species','Group','IUCN','CITES'])
            .sort_values(by='trade').Habitat.values
                     )[::-1]

# %%
# Draw a nested boxplot to show bills by day and time
sns.boxplot(x='trade', y="Habitat",
            hue="Habitat", 
            #hue_order = cat_ord,
            palette=['#d2b48c', '#654321', '#778899','#000000', '#FFFFFF', '#add8e6','#00008b'],
            saturation=1,
            data=trade_HAB,
            showfliers=False,
            order=plot_order_habitat,
            #ax=ax,
            notch=True,
            boxprops=dict(alpha=.7)
           );

# %%
# = = = = = Set up plot
_, ax = plt.subplots(1,1,figsize=(7, 5))

# Set colour pallette
sns.set_theme(style="ticks", palette="hls")

# Data
tmpdata = tmp_exSPH
varx = 'logTrade'

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x='trade', y="Habitat",
            hue="Habitat", 
            #hue_order = cat_ord,
            palette=['#d2b48c', '#654321', '#778899','#000000', '#FFFFFF', '#add8e6','#00008b'],
            saturation=1,
            data=trade_HAB,
            showfliers=False,
            order=plot_order_habitat,
            ax=ax,
            notch=True,
            #boxprops=dict(alpha=.7)
           ).set(
    #xlim=(-500, 20000),
    #xticks=(0,5000,10000,15000,20000),
    ylabel='', 
    xlabel='Exports (t)',
)

sns.stripplot(x='trade', y="Habitat",
            hue="Habitat", 
            #hue_order = cat_ord,
            palette=['#d2b48c', '#654321', '#778899','#000000', '#FFFFFF', '#add8e6','#00008b'],
            data=trade_HAB,
              edgecolor='black', linewidth=.5, zorder=10,
            order=plot_order_habitat,
              #alpha=0.3,
            ax=ax).set(
    ylabel='', 
    xlabel='Exports (t)',
)

#ADD NUMBER OF SPECIES>100t IN PARENTHESES NEXT TO GROUP

#plt.savefig(bf+'/Global/'+'Exports_vs_Habitat.jpg',dpi=300);
# Out:
# [Text(0, 0.5, ''), Text(0.5, 0, 'Exports (t)')]

# %%
sdata.head(3)
# Out:
#    logReported_species_landings  species_spp_id  country_spp_id  year_spp_id  \
# 0                      1.609438              57               2            0
# 1                      1.791759              57               2            1
# 2                      2.197225              57               2            2
#
#   country    year                 species       Habitat  \
# 0     ARG  year_1  Atlantoraja castelnaui  Coastal Rays
# 1     ARG  year_2  Atlantoraja castelnaui  Coastal Rays
# 2     ARG  year_3  Atlantoraja castelnaui  Coastal Rays
#
#    Reported_species_landings
# 0                        5.0
# 1                        6.0
# 2                        9.0

# %%
# Grab reported composition of species
sdata['Habitat'] = hdata.HabitatGroup[match(sdata.species,list(hdata.species_binomial))].values
sdata['Reported_species_landings'] = np.exp(sdata.logReported_species_landings)

# %%
# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="Reported_species_landings", y="Habitat",
            hue="Habitat", 
            #hue_order = cat_ord,
            palette=['#d2b48c', '#654321', '#778899','#000000', '#FFFFFF', '#add8e6'],
            saturation=1,
            data=sdata,
            showfliers=False,
            order=plot_order_habitat[:-1],
            #ax=ax,
            notch=True,
            boxprops=dict(alpha=.7)
           ).set(
    #xlim=(-1000, 200000),
    #xticks=(0,25000,50000,75000,100000),
    ylabel='', 
    xlabel='Annual exports (t)',
)
# Out:
# [Text(0, 0.5, ''), Text(0.5, 0, 'Annual exports (t)')]

# %%
hprops_old = sdata.groupby('Habitat').sum().drop(columns=['year_spp_id','species_spp_id',
                                             'logReported_species_landings','country',
                                             'year','species','country_spp_id']).loc[plot_order_habitat[:-1]]
hprops_old = hprops_old.Reported_species_landings/hprops_old.Reported_species_landings.sum()

# %%
hprops_old
# Out:
# Habitat
# Coastal Rays        0.137208
# Coastal Sharks      0.194921
# Pelagic Sharks      0.627655
# Deepwater Sharks    0.026360
# Deepwater Rays      0.013296
# Pelagic Rays        0.000559
# Name: Reported_species_landings, dtype: float64

# %%
hprops_new = trade_HAB.drop(columns=['draw','chain']).groupby('Habitat').mean().loc[plot_order_habitat]
hprops_new = hprops_new.trade/hprops_new.trade.sum()

# %%
hprops_new
# Out:
# Habitat
# Coastal Rays        0.394685
# Coastal Sharks      0.240816
# Pelagic Sharks      0.225017
# Deepwater Sharks    0.063665
# Deepwater Rays      0.049182
# Pelagic Rays        0.019461
# Freshwater Rays     0.007173
# Name: trade, dtype: float64

# %%
# Net difference in species compositions between landings and trade
props_diff = (hprops_new-hprops_old).loc[plot_order_habitat]
# Deal with freshwater rays
props_diff[np.isnan(props_diff)] = 0

# %%
# = = = = = Set up plot
_, ax = plt.subplots(1,2,figsize=(10, 5),width_ratios=(1.5,2))

# Set colour pallette
sns.set_style("white")
#sns.set_theme(style="ticks", palette="hls")


# Barplot of relative change in composition
ax[0].barh(y=np.arange(len(hprops_new)), width=props_diff[::-1]*100, 
         color=['#d2b48c', '#654321', '#00008b','#000000', '#FFFFFF', '#add8e6','#00008b'][::-1],
        )
ax[0].axvline(x=0,color='grey', linestyle=':', zorder=10)
ax[0].set_xlabel('Landings - trade (%)')
ax[0].axes.get_yaxis().set_visible(False)
ax[0].spines['left'].set_color('none')
ax[0].set_xlim(-40,50)

# Data
tmpdata = trade_HAB
varx = 'trade'

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x=varx, y="Habitat",
            hue="Habitat", 
            #hue_order = cat_ord,
            palette=['#d2b48c', '#654321', '#778899','#000000', '#FFFFFF', '#add8e6','#00008b'],
            saturation=1,
            data=tmpdata,
            showfliers=False,
            order=plot_order_habitat,
            ax=ax[1],
            notch=True,
            boxprops=dict(alpha=.7)
           ).set(
    #xlim=(-1000, 200000),
    xticks=(0,25000,50000,75000,100000),
    ylabel='', 
    xlabel='Annual exports (t)',
)
sns.despine()
ax[1].axvline(x=0,color='grey', linestyle=':', zorder=10)
ax[1].tick_params(axis='x', labelrotation=45)
ax[1].spines['left'].set_color('none')

#ADD NUMBER OF SPECIES>100t IN PARENTHESES NEXT TO GROUP

plt.savefig(bf+'/Global/'+'Exports_vs_Habitat.jpg',dpi=300);

# %%
# Grab IUCN status
tmp = rdata.Rlcategory[match(trade_noBS.species,list(rdata.species_))].to_numpy()

# %%
# Make endangered and critically endangered 
trade_noBS['iucn'] = np.array(['Not','Endangered'])[((tmp=='CR') + (tmp=='EN'))*1]

# %%
trade_noBS_hi = (trade_noBS.drop(columns=['exporter','species','Exporter'])
                 .groupby(['chain','draw','Habitat','iucn']).sum()
                 .reset_index())

# %%
tmp = trade_noBS_hi.drop(columns=['chain','draw']).groupby(['Habitat','iucn']).median().reset_index()
trad_hab_en = tmp[tmp.iucn=='Endangered'][['Habitat','trade']].set_index('Habitat')
trad_hab_no = tmp[tmp.iucn!='Endangered'][['Habitat','trade']].set_index('Habitat')

# %%
trad_hab_en
# Out:
#                          trade
# Habitat
# Coastal Rays      43414.697000
# Coastal Sharks    13579.296189
# Deepwater Rays       20.856238
# Deepwater Sharks   2225.332103
# Freshwater Rays      68.749558
# Pelagic Rays       2165.300076
# Pelagic Sharks    29198.596483

# %%
# Create IUCN pie for habitat plot
piedata_H = trad_hab_en
piedata_H['Endangered'] = trad_hab_en.trade
piedata_H['Not_Endangered'] = trad_hab_no.trade
piedata_H['trade'] = trad_hab_en.trade+trad_hab_no.trade
piedata_H['Endangered_prop'] = piedata_H.Endangered/(piedata_H.Endangered+piedata_H.Not_Endangered)
piedata_H['Not_prop'] = piedata_H.Not_Endangered/(piedata_H.Endangered+piedata_H.Not_Endangered)

# %%
piedata_H['l90'] = trade_HAB.groupby(['Habitat']).quantile(0.05).trade.values
piedata_H['l50'] = trade_HAB.groupby(['Habitat']).quantile(0.25).trade.values
piedata_H['u50'] = trade_HAB.groupby(['Habitat']).quantile(0.75).trade.values
piedata_H['u90'] = trade_HAB.groupby(['Habitat']).quantile(0.95).trade.values
# Add location for y plotting
piedata_H['yloc'] = np.arange(len(piedata_H.index.values))[::-1]

# %%
piedata_H.head()
# Out:
#                          trade    Endangered  Not_Endangered  Endangered_prop  \
# Habitat
# Coastal Rays      93498.073548  43414.697000    50083.376548         0.464338
# Coastal Sharks    57945.391261  13579.296189    44366.095072         0.234346
# Deepwater Rays    11791.762271     20.856238    11770.906034         0.001769
# Deepwater Sharks  13795.194732   2225.332103    11569.862629         0.161312
# Freshwater Rays     185.761436     68.749558      117.011879         0.370096
#
#                   Not_prop           l90           l50            u50  \
# Habitat
# Coastal Rays      0.535662  70516.100041  81204.954963  104426.571671
# Coastal Sharks    0.765654  47007.753489  53916.312319   64079.393514
# Deepwater Rays    0.998231   7555.503349   9742.113218   14515.653183
# Deepwater Sharks  0.838688  10445.217968  12506.738337   17981.521373
# Freshwater Rays   0.629904     44.122595    108.613859     755.880474
#
#                             u90  yloc
# Habitat
# Coastal Rays      179233.616363     6
# Coastal Sharks     75148.735703     5
# Deepwater Rays     18631.085089     4
# Deepwater Sharks   25135.598740     3
# Freshwater Rays    19282.026947     2

# %%
# Index order
piedata_H['yloc'] = match(piedata_H.index.values,list(plot_order_habitat[::-1]))

# %%
# Get trade by species without blue shark
tmp = spp_exports.drop_sel(species='Prionace glauca').median(('chain','draw')).to_dataframe().rename(columns={"":'trade'}).reset_index()
tmp = tmp[tmp.trade>100]
tmp['Habitat'] = hdata.HabitatGroup[match(tmp.species,list(hdata.species_binomial))].values
# Grab Habitat numbers of species per habitat >100t in trade
values, counts = np.unique(tmp['Habitat'], return_counts=True)
hab_spp_counts = pd.Series(np.append(counts,0),index=np.append(values,('Freshwater Rays')))[plot_order_habitat]

# %%
# Labels
tmp_lab = plot_order_habitat[::-1]
tmp_lab = [a+' ('+str(b)+'}' for a,b in zip(tmp_lab,hab_spp_counts.values[::-1])]
tmp_lab
# Out:
# ['Freshwater Rays (0}',
#  'Pelagic Rays (2}',
#  'Deepwater Rays (16}',
#  'Deepwater Sharks (11}',
#  'Pelagic Sharks (32}',
#  'Coastal Sharks (34}',
#  'Coastal Rays (43}']

# %%
# = = = = = Set up plot
_, ax = plt.subplots(1,2,figsize=(8, 4),width_ratios=(1.3,2))

# Set colour pallette
sns.set_style("white")
#sns.set_theme(style="ticks", palette="hls")


# Barplot of relative change in composition
ax[0].barh(y=np.arange(len(hprops_new)), width=props_diff[::-1]*100, 
         color=['#d2b48c', '#654321', '#00008b','#000000', '#FFFFFF', '#add8e6','#00008b'][::-1],
        )
ax[0].axvline(x=0,color='grey', linestyle=':', zorder=10)
ax[0].set_xlabel('Net difference (%)')
ax[0].axes.get_yaxis().set_visible(False)
ax[0].spines[['left','right','top']].set_color('none')
ax[0].set_xlim(-40,80)
ax[0].set_xticks((-40,-20,0,20))


# Exporters
ax[1].scatter(x=piedata_H['trade'], y=piedata_H['yloc'], s=30, facecolor='white', edgecolors='none', zorder=11)
ax[1].plot((piedata_H['l90'],piedata_H['u90']), (piedata_H['yloc'],piedata_H['yloc']), c='black', linewidth=2, zorder=9)
ax[1].plot((piedata_H['l50'],piedata_H['u50']), (piedata_H['yloc'],piedata_H['yloc']), c='black', linewidth=5, zorder=9)

for xx,yy,xxr,yyr,c in zip(piedata_H['trade'],
                         piedata_H['yloc'],
                         piedata_H['Endangered_prop'].values,
                         piedata_H['Not_prop'].values-0.001,
                        ['#d2b48c', '#654321', '#00008b','#000000', '#FFFFFF', '#add8e6','#00008b']):
    drawPieMarker(xs=xx,
                  ys=yy,
                  ratios=[xxr,yyr],
                  sizes=[300],
                  colors=['red', c],
                  #edgecolor='black',
                  ax=ax[1])

ax[1].set_yticks(np.arange(len(tmp_lab)))
ax[1].set_yticklabels(tmp_lab)
#[tk.set_visible(True) for tk in ax[1].get_yticklabels()]
ax[1].set_xlabel('(t/yr)')
#ax[1].set_xlim(-500,topx)
#ax[1].set_title('')
#ax[1].legend_.remove()
legend_elements = [patches.Patch(facecolor='red', label='Endangered')]
ax[1].legend(handles=legend_elements)


ax[1].axvline(x=0,color='grey', linestyle=':', zorder=10)
ax[1].tick_params(axis='x', labelrotation=45)
ax[1].spines[['left','right','top']].set_color('none')

#ADD NUMBER OF SPECIES>100t IN PARENTHESES NEXT TO GROUP

plt.savefig(bf+'/Global/'+'Exports_vs_Habitat.jpg',dpi=300);

# %% [markdown]
# ## Revise figure
#
# left panel a) - plot net difference between proportions in each of the 7 categories in reported data minus proportion of total in the latent data: will be a plot of under or over representation in reported landings of these 7 groups.
#     - to show the degree of surprise in what we have uncovered
#
# panel b)  New doughnut plots of the figure able to add-in endangered in 2020 status

# %%
plt.axis?
# Out:
# Signature:
# plt.axis(
#     arg: 'tuple[float, float, float, float] | bool | str | None' = None,
#     /,
#     *,
#     emit: 'bool' = True,
#     **kwargs,
# ) -> 'tuple[float, float, float, float]'
# Docstring:
# Convenience method to get or set some axis properties.
#
# Call signatures::
#
#   xmin, xmax, ymin, ymax = axis()
#   xmin, xmax, ymin, ymax = axis([xmin, xmax, ymin, ymax])
#   xmin, xmax, ymin, ymax = axis(option)
#   xmin, xmax, ymin, ymax = axis(**kwargs)
#
# Parameters
# ----------
# xmin, xmax, ymin, ymax : float, optional
#     The axis limits to be set.  This can also be achieved using ::
#
#         ax.set(xlim=(xmin, xmax), ylim=(ymin, ymax))
#
# option : bool or str
#     If a bool, turns axis lines and labels on or off. If a string,
#     possible values are:
#
#     ================ ===========================================================
#     Value            Description
#     ================ ===========================================================
#     'off' or `False` Hide all axis decorations, i.e. axis labels, spines,
#                      tick marks, tick labels, and grid lines.
#                      This is the same as `~.Axes.set_axis_off()`.
#     'on' or `True`   Do not hide all axis decorations, i.e. axis labels, spines,
#                      tick marks, tick labels, and grid lines.
#                      This is the same as `~.Axes.set_axis_on()`.
#     'equal'          Set equal scaling (i.e., make circles circular) by
#                      changing the axis limits. This is the same as
#                      ``ax.set_aspect('equal', adjustable='datalim')``.
#                      Explicit data limits may not be respected in this case.
#     'scaled'         Set equal scaling (i.e., make circles circular) by
#                      changing dimensions of the plot box. This is the same as
#                      ``ax.set_aspect('equal', adjustable='box', anchor='C')``.
#                      Additionally, further autoscaling will be disabled.
#     'tight'          Set limits just large enough to show all data, then
#                      disable further autoscaling.
#     'auto'           Automatic scaling (fill plot box with data).
#     'image'          'scaled' with axis limits equal to data limits.
#     'square'         Square plot; similar to 'scaled', but initially forcing
#                      ``xmax-xmin == ymax-ymin``.
#     ================ ===========================================================
#
# emit : bool, default: True
#     Whether observers are notified of the axis limit change.
#     This option is passed on to `~.Axes.set_xlim` and
#     `~.Axes.set_ylim`.
#
# Returns
# -------
# xmin, xmax, ymin, ymax : float
#     The axis limits.
#
# See Also
# --------
# matplotlib.axes.Axes.set_xlim
# matplotlib.axes.Axes.set_ylim
#
# Notes
# -----
# For 3D axes, this method additionally takes *zmin*, *zmax* as
# parameters and likewise returns them.
# File:      ~/miniforge3/envs/gsm-project/lib/python3.11/site-packages/matplotlib/pyplot.py
# Type:      function

# %% [markdown]
# ## Plot strong demand scores among top trading nations

# %%
spp_demand = trade_spp.sel(importer=trade_cou).sum(('importer')).rename("").assign_coords({"CITES": ("species", CITES)})
listed_exports = spp_exports[:,:,:,spp_exports.CITES=='Listed']
unlisted_exports = spp_exports[:,:,:,spp_exports.CITES!='Listed']
prop_listed_exports = listed_exports.sum('species')/spp_exports.sum('species')

# %%
spp_demand = idata_trade_a.posterior['importer_species_effect'].sel(importer=trade_cou)

# %%
# Top trading nations species demand scores
demand_spp = []
demand_c = []
for c in trade_cou:
    # Select top 10% of traded species
    tmp = idata_trade_a.posterior['importer_species_effect'].sel(importer=c).mean(('chain'))
    if np.any(tmp.quantile(0.5,dim='draw')>0):
        try:
            spx = tmp.species[tmp.quantile(0.05,dim='draw')>0].values
            demand_spp += list(spx)
            demand_c += [c]*len(spx)
        except:
            pass
demand_spp = np.array(demand_spp).flatten()
demand_c = np.array(demand_c)

# %%
# All trading nations species demand scores
demand_spp_A = []
demand_c_A = []
for c in country_:
    # Select top 10% of traded species
    tmp = idata_trade_a.posterior['importer_species_effect'].sel(importer=c).mean(('chain'))
    if np.any(tmp.quantile(0.5,dim='draw')>0):
        try:
            spx = tmp.species[tmp.quantile(0.05,dim='draw')>0].values
            demand_spp_A += list(spx)
            demand_c_A += [c]*len(spx)
        except:
            pass
demand_spp_A = np.array(demand_spp_A).flatten()
demand_c_A = np.array(demand_c_A)

# %%
# Grab IUCN for augmented data
IUCN_t = rdata.Rlcategory[match(idata_trade_a.posterior['importer_species_effect'].species,list(rdata.species_))].to_numpy()

# %%
az.style.use("arviz-darkgrid")

# %%
country_
# Out:
# array(['AGO', 'ARE', 'ARG', 'AUS', 'BEL', 'BGD', 'BLZ', 'BRA', 'CAN',
#        'CHL', 'CHN', 'CMR', 'COL', 'CRI', 'CUB', 'DEU', 'DNK', 'ECU',
#        'ESP', 'FRA', 'GBR', 'GHA', 'GRC', 'HKG', 'IDN', 'IND', 'IRL',
#        'IRN', 'ITA', 'JPN', 'KOR', 'LBY', 'LKA', 'MAR', 'MDG', 'MEX',
#        'MOZ', 'MRT', 'MYS', 'NAM', 'NGA', 'NLD', 'NOR', 'NZL', 'OMN',
#        'PAK', 'PAN', 'PER', 'PHL', 'POL', 'PRT', 'RUS', 'SEN', 'SGP',
#        'SLE', 'SWE', 'THA', 'TTO', 'TUN', 'TWN', 'TZA', 'URY', 'USA',
#        'VEN', 'VUT', 'YEM', 'ZAF'], dtype='<U3')

# %%
# Grab dataframe object
tmp = idata_trade_a.posterior['importer_species_effect'].assign_coords({"IUCN": ("species", IUCN_t)}).sel(importer=xr.DataArray(list(demand_c), dims='z'), species=xr.DataArray(list(demand_spp), dims='z'))
tmp = tmp[:,:,np.argsort(tmp.median(('chain','draw')).values)[::-1]].rename("")
tmp.Importer.loc[tmp.Importer=='Rep. of Korea'] = 'S. Korea'
# IUCN colours per species
coulx = np.array(['#35193e', '#ad1759', '#e13342', '#f37651', 'darkgrey', 'black'])[np.array([cat_ord.index(x) for x in tmp.IUCN.values])]


ax = az.plot_forest([tmp[:,:,i] for i in range(tmp.shape[2])],
                    hdi_prob=0.9,
                    kind='forestplot',
                    figsize=(5, 5),
                    combined=True,
                    colors=list(coulx),
                    legend=False
                   )
ax[0].set(
    title="Importer preferences",
    xlabel="log-Odds",
    ylabel="",
)

ax[0].axvline(0, color="darkgrey", linestyle="dotted")

#ax[0].set_xlim(0,0.5)
for tick in ax[0].get_xticklabels():
    tick.set_rotation(45)
tmp_lab = np.array([y+' | '+x for x,y in zip(tmp.species.values, tmp.Importer.values)])[::-1]
ax[0].set_yticklabels(tmp_lab)
ax[0].tick_params(labelleft=False, left=False)
ax[0].tick_params(labelright=True, right=False)
plt.savefig(bf+'/Global/'+'Importer_species_demand.jpg',dpi=300);

# %%
# Grab dataframe object
tmp = idata_trade_a.posterior['importer_species_effect'].assign_coords({"IUCN": ("species", IUCN_t)}).sel(importer=xr.DataArray(list(demand_c_A), dims='z'), species=xr.DataArray(list(demand_spp_A), dims='z'))
tmp = tmp[:,:,np.argsort(tmp.median(('chain','draw')).values)[::-1]].rename("")
tmp.Importer.loc[tmp.Importer=='Rep. of Korea'] = 'S. Korea'
# IUCN colours per species
coulx = np.array(['#35193e', '#ad1759', '#e13342', '#f37651', 'darkgrey', 'black'])[np.array([cat_ord.index(x) for x in tmp.IUCN.values])]


ax = az.plot_forest([tmp[:,:,i] for i in range(tmp.shape[2])],
                    hdi_prob=0.9,
                    kind='forestplot',
                    figsize=(5, 6),
                    combined=True,
                    colors=list(coulx),
                    legend=False
                   )
ax[0].set(
    title="Importer preferences",
    xlabel="log-Odds",
    ylabel="",
)

ax[0].axvline(0, color="darkgrey", linestyle="dotted")

#ax[0].set_xlim(0,0.5)
for tick in ax[0].get_xticklabels():
    tick.set_rotation(45)
tmp_lab = np.array([y+' | '+x for x,y in zip(tmp.species.values, tmp.Importer.values)])[::-1]
ax[0].set_yticklabels(tmp_lab)
ax[0].tick_params(labelleft=False, left=False)
ax[0].tick_params(labelright=True, right=False)
plt.savefig(bf+'/Global/'+'Importer_species_demand_ALL.jpg',dpi=300);

# %% [markdown]
# ## Plot major importer demand by species prefs

# %%
plot_order_im.values
# Out:
# array(['KOR', 'PRT', 'BRA', 'ITA', 'MYS', 'ESP', 'CHN', 'FRA', 'URY',
#        'THA'], dtype='<U3')

# %%
# Index top importers for demand scores
dindx = []
for x in plot_order_im.values:
    if x in tmp.importer:
        dindx += [list(tmp.importer).index(x)]
dindx = np.array(dindx)
# Subset xarray for top importers
top_tmp = tmp[:,:,dindx]

# %%
# IUCN colours per species
coulx = np.array(['#35193e', '#ad1759', '#e13342', '#f37651', 'darkgrey', 'black'])[np.array([cat_ord.index(x) for x in top_tmp.IUCN.values])]

# %%
ax = az.plot_forest([top_tmp[:,:,i] for i in range(top_tmp.shape[2])],
                    hdi_prob=0.9,
                    kind='forestplot',
                    figsize=(4, 4),
                    combined=True,
                    colors=list(coulx),
                    legend=False
                   )
ax[0].set(
    title="Importer preferences",
    xlabel="log-Odds",
    ylabel="",
)

ax[0].axvline(0, color="darkgrey", linestyle="dotted")

#ax[0].set_xlim(0,0.5)
for tick in ax[0].get_xticklabels():
    tick.set_rotation(45)
tmp_lab = np.array([y+', '+x for x,y in zip(top_tmp.species.values, top_tmp.Importer.values)])[::-1]
ax[0].set_yticklabels(tmp_lab);

# %% [markdown]
# ## Landings and trade maps

# %%
# Reef-scale lat/lon
SSlat = np.array([np.mean(xdata.set_latitude.values[xdata.reef_id.values==R]) for R in Reef])
SSlon = np.array([np.mean(xdata.set_longitude.values[xdata.reef_id.values==R]) for R in Reef])
mp.pyplot.style.use('seaborn-darkgrid')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[146], line 2
#       1 # Reef-scale lat/lon
# ----> 2 SSlat = np.array([np.mean(xdata.set_latitude.values[xdata.reef_id.values==R]) for R in Reef])
#       3 SSlon = np.array([np.mean(xdata.set_longitude.values[xdata.reef_id.values==R]) for R in Reef])
#       4 mp.pyplot.style.use('seaborn-darkgrid')
#
# NameError: name 'Reef' is not defined

# %%
fig = plt.figure(figsize=(15, 5))
# Instantiate basemap
m = bm(llcrnrlon=-30,llcrnrlat=-47,urcrnrlon=334,urcrnrlat=67,projection='mill')
m.drawcoastlines()
m.drawcountries()
#m.fillcontinents()


"""
# Convert longitude
SSlon[SSlon<0] = SSlon[SSlon<0]+360
xx,yy = m(SSlon,SSlat)
cmap = co.cm.thermal
zz = np.array([cmap([p_reef[i]]) for i in range(nreefs)])


# Plot points
[plt.scatter(x, y, c=z, edgecolor='#909090', linewidth=0.7, s=70, alpha=1, marker=m, zorder=5) for x,y,z,m in zip(xx,yy,zz,rsym)];

#"""
cax = fig.add_axes([0.98, 0.01, 0.02, 0.975])
#norm = mp.colors.Normalize(vmin=min(mu_reef), vmax=max(mu_reef))
#cb = mp.colorbar.ColorbarBase(cax, cmap,label='Proportion of sets with sharks')

#fig.tight_layout()
#plt.savefig('Figure_1a.pdf');

# %% [markdown]
# # Information prioritization
#
# a) Average information gap vs biomass in the trade, coloured by IUCN category
# b) Average information gap per species vs total weighted information gap per country, shapes/colours by continent

# %%
# Information present for assigning to species in FAO data
IE_obs = -np.log(idata_landings_a.posterior.PsppIdent.sel(species=spp_100))

# %%
continent_ = np.array(['Africa', 'Asia', 'South America', 'Oceania',
       'Europe', 'Asia', 'North America', 'South America', 'North America', 'South America',
       'Asia', 'Africa', 'South America', 'North America', 'North America', 'Europe',
       'Europe', 'South America', 'Europe', 'Europe', 'Europe', 'Africa',
       'Europe', 'Asia', 'Oceania', 'Asia', 'Europe',
       'Asia', 'Europe', 'Asia', 'Asia', 'Africa', 'Asia',
       'Africa', 'Africa', 'North America', 'Africa', 'Africa',
       'Asia', 'Africa', 'Africa', 'Europe', 'Europe',
       'Oceania', 'Asia', 'Asia', 'North America', 'South America', 'Asia',
       'Europe', 'Europe', 'Asia', 'Africa', 'Asia',
       'Africa', 'Europe', 'Asia', 'North America',
       'Africa', 'Asia', 'Africa', 'South America',
       'North America', 'South America', 'Asia', 'Oceania', 'Asia', 'Africa'])

# %%
# Average information gap per species
mean_IG_spp = IE_obs.where(IE_obs != 0.).mean(('chain','draw','exporter'))

# Total biomass in the trade
trade_vol_spp = (idata_trade_a.posterior.amount_exported.mean(('chain','draw')).sum(('exporter','importer'))
                 .assign_coords({"IUCN": ("species", IUCN_all)})
                .assign_coords({"Habitat": ("species", hdata.HabitatGroup[match(species_,list(hdata.species_binomial))].values)})
                )
# Index of IUCN per spp

# Average information gap per exporter - calculated for species >0 (i.e. that are present)
mean_IG_ex = IE_obs.where(IE_obs != 0.).mean(('chain','draw','species'), skipna=None)

# Exporter's proportion of trade
trade_vol_ex = idata_trade_a.posterior.amount_exported.mean(('chain','draw')).sum(('species','importer')).assign_coords({"Continent": ("exporter", continent_)})
trade_vol_prop = trade_vol_ex/sum(trade_vol_ex)

# Total information per country
total_IG_ex = IE_obs.mean(('chain','draw')).sum('species')
# Weighted total information per country
total_IGw_ex = total_IG_ex*trade_vol_prop

# %%
list(piedata_H.index.values)
# Out:
# ['Coastal Rays',
#  'Coastal Sharks',
#  'Deepwater Rays',
#  'Deepwater Sharks',
#  'Freshwater Rays',
#  'Pelagic Rays',
#  'Pelagic Sharks']

# %%
# = = = = = Set up plot
_, ax = plt.subplots(1,2,figsize=(8, 4))

miy = 0.2

# a) Average information gap vs biomass in the trade, coloured by IUCN category
cony = ['DD', 'LC', 'NT', 'VU', 'EN', 'CR']
ccoy = np.array([3,2,2,3,4,4])[match(trade_vol_spp.IUCN,cony)]
ccox = np.array(['black','black','black','black','red','red'])[match(trade_vol_spp.IUCN,cony)]
ccow = np.array([.5,.5,.5,.5,.7,.7])[match(trade_vol_spp.IUCN,cony)]
ccoz = np.array(['s',"o","o","o","o","o"])[match(trade_vol_spp.IUCN,cony)]
conx = ['Coastal Rays','Coastal Sharks','Deepwater Rays','Deepwater Sharks','Pelagic Rays','Pelagic Sharks']
colx = ['#d2b48c', '#654321', '#555555','#000000', '#add8e6','#00008b']
ccol = np.array(colx)[match(trade_vol_spp.sel(species=spp_100).Habitat,conx)]
cutz = match(spp_100,list(species_))
icol = ccol
[ax[0].scatter(x, y, facecolor=c, s=(3*s)**2, marker=m,
               edgecolor=z,linewidth=w) for x,y,c,s,m,z,w in zip(
                (trade_vol_spp.sel(species=spp_100)), 
                mean_IG_spp.sel(species=spp_100), 
                icol,
                ccoy,
                ccoz,
                ccox,
                ccow
                )]

#legend_elements = [patches.Patch(facecolor='red', label='Endangered c.2020', edgecolor='black', linewidth=0.5)]
legend_elements1 = [patches.Patch(facecolor=c, label=i, edgecolor='black', linewidth=0.5) for i,c in zip(conx, colx)]
legend1 = ax[0].legend(handles=legend_elements1, fontsize=10)
ax[0].add_artist(legend1)
ax[0].legend(fontsize=10)
ax[0].set_xlabel('Total trade (t)')
ax[0].set_ylabel('Mean information gap')
ax[0].set(
    #xscale="log", 
    xlim=(-500, 35000),
    ylim=(miy, 1.4))
ax[0].xaxis.grid(True, "minor", linewidth=.5)
ax[0].yaxis.grid(False)
for tick in ax[0].get_xticklabels():
    tick.set_rotation(45)

# b) Average information gap per species vs total weighted information gap per country, shapes/colours by continent
conx = ['Africa', 'Asia', 'S America', 'Oceania', 'Europe','N America']
colx = mp.colormaps['Accent'].resampled(len(conx))
ccol = colx(match(trade_vol_ex.Continent.values,['Africa', 'Asia', 'South America', 'Oceania', 'Europe','North America']))
[ax[1].scatter(x,s,color=c, s=(y/10)**3, edgecolor='black', linewidth=0.5) for x,y,s,c in zip(trade_vol_ex, total_IG_ex, mean_IG_ex, ccol)]
legend_elements1 = [patches.Patch(facecolor=c, label=i, edgecolor='black', linewidth=0.5) for i,c in zip(conx, colx(np.arange(len(conx))))]
legend1 = ax[1].legend(handles=legend_elements1, fontsize=10)
ax[1].add_artist(legend1)

gll = plt.scatter([],[], s=5, marker='o', color='white', edgecolor='black')
gl = plt.scatter([],[], s=50, marker='o', color='white', edgecolor='black')
ga = plt.scatter([],[], s=150, marker='o', color='white', edgecolor='black')
gk = plt.scatter([],[], s=400, marker='o', color='white', edgecolor='black')

ax[1].legend((gl,ga,gk),
       ('35', '50','75'),
       scatterpoints=1,
       loc='lower left',
       ncol=1,
       fontsize=8,
        title='$\Sigma$ IG',
        bbox_to_anchor=(.47, .05))


ax[1].set_xlabel('Total trade (t)')
ax[1].set_ylabel('')
ax[1].set(
    #xscale="log", 
    xlim=(None, None),
    ylim=(miy, 1.4))
ax[1].xaxis.grid(True, "minor", linewidth=.5)
for tick in ax[1].get_xticklabels():
    tick.set_rotation(45)
ax[1].set_xticks((0,30000,60000,90000,120000))
ax[1].axes.get_yaxis().set_visible(False)

plt.savefig(bf+'/Global/'+'Information_gaps.jpg',dpi=300);
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
np.unique(trade_vol_spp.Habitat)
# Out:
# array(['Coastal Rays', 'Coastal Sharks', 'Deepwater Rays',
#        'Deepwater Sharks', 'Freshwater Rays', 'Pelagic Rays',
#        'Pelagic Sharks'], dtype=object)

# %%
min(total_IG_ex)
# Out:
# <xarray.DataArray 'PsppIdent' ()>
# array(9.18324403)
# Coordinates:
#     exporter  <U3 'IRN'
#     Exporter  object 'Iran'

# %%
# = = = = = Set up plot
_, ax = plt.subplots(1,2,figsize=(16, 10))

spp_100 = spp_100[spp_100!='Prionace glauca']

miy = 0.2
# a) Average information gap vs biomass in the trade, coloured by IUCN category
cony = ['DD', 'LC', 'NT', 'VU', 'EN', 'CR']
ccoy = np.array([3,2,2,3,4,4])[match(trade_vol_spp.IUCN,cony)]
ccox = np.array(['black','black','black','black','red','red'])[match(trade_vol_spp.IUCN,cony)]
ccow = np.array([.5,.5,.5,.5,.7,.7])[match(trade_vol_spp.IUCN,cony)]
ccoz = np.array(['s',"o","o","o","o","o"])[match(trade_vol_spp.IUCN,cony)]
conx = ['Coastal Rays','Coastal Sharks','Deepwater Rays','Deepwater Sharks','Pelagic Rays','Pelagic Sharks']
colx = ['#d2b48c', '#654321', '#555555','#000000', '#add8e6','#00008b']
ccol = np.array(colx)[match(trade_vol_spp.sel(species=spp_100).Habitat,conx)]
cutz = match(spp_100,list(species_))
icol = ccol
[ax[0].scatter(x, y, facecolor=c, s=(3*s)**2, marker=m,
               edgecolor=z,linewidth=w) for x,y,c,s,m,z,w in zip(
                (trade_vol_spp.sel(species=spp_100)), 
                mean_IG_spp.sel(species=spp_100), 
                icol,
                ccoy,
                ccoz,
                ccox,
                ccow
                )]
[ax[0].text(x, y, t, fontsize=6) for x,y,t in zip(
                (trade_vol_spp.sel(species=spp_100)), 
                mean_IG_spp.sel(species=spp_100), 
                spp_100
                )]
#[ax[0].text(x,y,'test', fontsize=9) for x,s,t in zip((trade_vol_spp.sel(species=spp_100)), mean_IG_spp.sel(species=spp_100), spp_100)]

#legend_elements = [patches.Patch(facecolor='red', label='Endangered c.2020', edgecolor='black', linewidth=0.5)]
legend_elements1 = [patches.Patch(facecolor=c, label=i, edgecolor='black', linewidth=0.5) for i,c in zip(conx, colx)]
legend1 = ax[0].legend(handles=legend_elements1, fontsize=10)
ax[0].add_artist(legend1)
ax[0].legend(fontsize=10)
ax[0].set_xlabel('Total trade (t)')
ax[0].set_ylabel('Mean information gap')
ax[0].set(
    #xscale="log", 
    #xlim=(-500, 35000),
    #ylim=(miy, 1.4)
)
ax[0].xaxis.grid(True, "minor", linewidth=.5)
ax[0].yaxis.grid(False)
for tick in ax[0].get_xticklabels():
    tick.set_rotation(45)

# b) Average information gap per species vs total weighted information gap per country, shapes/colours by continent
conx = ['Africa', 'Asia', 'S America', 'Oceania', 'Europe','N America']
colx = mp.colormaps['Accent'].resampled(len(conx))
ccol = colx(match(trade_vol_ex.Continent.values,['Africa', 'Asia', 'South America', 'Oceania', 'Europe','North America']))
[ax[1].scatter(x,s,color=c, s=(y/10)**3, edgecolor='black', linewidth=0.5) for x,y,s,c in zip(trade_vol_ex, total_IG_ex, mean_IG_ex, ccol)]
[ax[1].text(x,s, t, fontsize=9) for x,s,t in zip(trade_vol_ex, mean_IG_ex, country_)]

legend_elements1 = [patches.Patch(facecolor=c, label=i, edgecolor='black', linewidth=0.5) for i,c in zip(conx, colx(np.arange(len(conx))))]
legend1 = ax[1].legend(handles=legend_elements1, fontsize=10)
ax[1].add_artist(legend1)

gll = plt.scatter([],[], s=5, marker='o', color='white', edgecolor='black')
gl = plt.scatter([],[], s=50, marker='o', color='white', edgecolor='black')
ga = plt.scatter([],[], s=150, marker='o', color='white', edgecolor='black')
gk = plt.scatter([],[], s=400, marker='o', color='white', edgecolor='black')

ax[1].legend((gl,ga,gk),
       ('35', '50','75'),
       scatterpoints=1,
       loc='lower left',
       ncol=1,
       fontsize=8,
        title='$\Sigma$ IG',
        bbox_to_anchor=(.47, .05))


ax[1].set_xlabel('Total trade (t)')
ax[1].set_ylabel('')
ax[1].set(
    #xscale="log", 
    #xlim=(None, None),
    #ylim=(miy, 1.4)
)
ax[1].xaxis.grid(True, "minor", linewidth=.5)
for tick in ax[1].get_xticklabels():
    tick.set_rotation(45)
ax[1].set_xticks((0,30000,60000,90000,120000))
ax[1].axes.get_yaxis().set_visible(False)

plt.savefig(bf+'/Global/'+'Information_gaps_label.jpg',dpi=300);
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
